# %%
import pandas as pd
import numpy as np

# %%
import pickle
with open('data/bystore.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
len(data[1][0])
# Out:
# 511

# %% [markdown]
# # 데이터 정제

# %% [markdown]
# ## 날짜/메뉴 데이터 병합

# %%
# 메뉴 리스트 정제 함수
def cleaner1(index, drop):
    dic = {}
    n = 0
    dic[0] = []
    exc = ['', '배달팁', '(A) 매출금액', '(B) 고객할인비용', '(C) 차감금액', '(D) 부가세', '(E) 만나서결제금액', '입금예정금액 (A+B+C+D)', '입금예정금액 (A+B+C+D+E)']
    exc.append(drop)

    for i in data[index][1]:
        if i == '총 결제금액':
            n += 1
            dic[n] = []
            pass
        elif i in exc:
            pass
        else:
            dic[n].append(i)
    space = len(dic)-1
    del dic[space]
    return list(dic.values())

# %%
# 날짜와 병합하여 df 만들기
df = pd.concat((pd.DataFrame([i.split('\n') for i in data[1][0]]), pd.DataFrame(pd.Series(cleaner1(1, drop='┗ 기본')))), axis=1)
df.columns = ['date', 'time', 'menu']
df
# Out:
#                   date         time  \
# 0    2022. 06. 21. (화)  오후 08:49:04
# 1    2022. 06. 21. (화)  오후 08:41:02
# 2    2022. 06. 21. (화)  오후 07:35:21
# 3    2022. 06. 21. (화)  오후 07:00:28
# 4    2022. 06. 21. (화)  오후 06:19:00
# ..                 ...          ...
# 506  2022. 03. 24. (목)  오후 05:44:46
# 507  2022. 03. 24. (목)  오후 05:11:01
# 508  2022. 03. 24. (목)  오후 12:44:41
# 509  2022. 03. 24. (목)  오전 11:35:48
# 510  2022. 03. 24. (목)  오전 10:46:23
#
#                                                   menu
# 0                         [직화바베큐 치밥도시락\n1개, ┗ 야끼만두 5개]
# 1    [매콤양념 치밥도시락\n1개, ┗ 푸딩스퇄 계란찜 大 추가, ┗ 쿨피스 캔 350m...
# 2    [직화바베큐 치밥도시락\n1개, ┗ 고기 100g 추가, ┗ 쿨피스 캔 350ml ...
# 3    [직화양념 치밥도시락 (매콤) (지코X 스타일)\n1개, ┗ ㄹlㅇ뷰 ㅇl벤트(쿨피...
# 4            [직화바베큐 치밥도시락\n1개, ┗ ㄹlㅇ뷰 ㅇl벤트(왕새우 튀김 2개)]
# ..                                                 ...
# 506  [고기만 2배 (밥X)\n1개, ┗ 직화양념 (매콤) (지코X 스타일), 마늘간장 ...
# 507        [직화양념 치밥도시락 (매콤) (지코X 스타일)\n1개, ┗ 한입핫도그 5개]
# 508                      [갈비천왕 치밥도시락\n1개, ┗ 피카츄돈까스 1개]
# 509                    [직화양념 치밥도시락 (매콤) (지코X 스타일)\n2개]
# 510                                                NaN
#
# [511 rows x 3 columns]

# %%
menu_main = ['치밥', '야끼만두', '게맛살', '멘보샤', '해쉬브라운', '우유튀김', '왕오징어튀김',
             '모듬튀김', '치즈스틱', '고구마튀김', '왕새우튀김', '김말이', '수제돈까스', '쿨피스', '펩시콜라', '사이다', '오란씨',
             '토핑추가', '떡볶이', '계란찜', '미니오뎅탕', '소떡소떡', '스노윙 치즈볼', '허니버터 치즈볼', '오뎅튀김',
             '셀프주먹밥', '한입핫도그', '생수', '카스', '테라', '참이슬', '진로', '시원']
menu_eng = ['Chibab', 'Yakimandu', 'Crab', 'Menbo', 'Hashbrown', 'milkfries', 'FriedSquid',
             'FriesSet', 'CheeseStick', 'SPFries', 'FriedShrimp', 'Kimmari', 'Donkats', 'Coolpeace', 'Pepsi', 'Cider', 'OranC',
             'Toppings', 'Teokboki', 'Gyeranzzim', 'Odengtang', 'Sotteock', 'Cheeseball', 'Cheeseball', 'FriedOdeng',
             'Selfjumeokbab', 'miniHotdog', 'Water', 'Cass', 'Tera', 'Chamisl', 'Jinro', 'Siwon']

menu_list = {}

for k, v in menus.items():
    menu_list[k] = []
    for e in v:
        for m, eng in zip(menu_main, menu_eng):
            if m in e:
                if m not in menu_list[k]:
                    menu_list[k].append(eng)
basket = []
for b in menu_list.values():
    if b == []:
        pass
    else:
        basket.append(b)
basket
# Out:
# [['Menbo'],
#  ['Chibab', 'FriedSquid', 'Teokboki', 'Kimmari'],
#  ['Sotteock', 'FriedSquid'],
#  ['Chibab', 'Pepsi'],
#  ['FriesSet'],
#  ['milkfries'],
#  ['SPFries'],
#  ['Chamisl'],
#  ['Chibab'],
#  ['Chibab', 'FriedShrimp'],
#  ['Selfjumeokbab', 'Pepsi'],
#  ['Teokboki', 'FriedSquid'],
#  ['Teokboki', 'Sotteock', 'Pepsi'],
#  ['Hashbrown', 'FriedSquid'],
#  ['FriedShrimp'],
#  ['Crab', 'Odengtang'],
#  ['Sotteock', 'Toppings'],
#  ['Coolpeace', 'FriedSquid'],
#  ['Menbo'],
#  ['Selfjumeokbab', 'Gyeranzzim'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab'],
#  ['Sotteock'],
#  ['Menbo'],
#  ['Coolpeace', 'Selfjumeokbab'],
#  ['Coolpeace', 'Coolpeace'],
#  ['Selfjumeokbab', 'Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Sotteock'],
#  ['Pepsi', 'Sotteock'],
#  ['Chibab', 'Pepsi'],
#  ['CheeseStick', 'Coolpeace'],
#  ['CheeseStick', 'Toppings'],
#  ['Chibab', 'Sotteock'],
#  ['Sotteock', 'Pepsi', 'Menbo'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Pepsi', 'Toppings'],
#  ['Menbo'],
#  ['Chibab', 'Sotteock', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki', 'Sotteock'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Coolpeace', 'Coolpeace'],
#  ['Chibab', 'OranC'],
#  ['Sotteock'],
#  ['Pepsi'],
#  ['FriesSet'],
#  ['Chibab', 'Menbo', 'Sotteock', 'Cider', 'CheeseStick'],
#  ['Hashbrown', 'Chibab'],
#  ['Chibab', 'Coolpeace'],
#  ['Jinro', 'Teokboki', 'Pepsi', 'Coolpeace', 'Odengtang', 'Teokboki'],
#  ['Toppings'],
#  ['Pepsi'],
#  ['Chibab', 'Cheeseball', 'Chibab', 'Coolpeace'],
#  ['Teokboki', 'Toppings', 'Coolpeace'],
#  ['Pepsi', 'Menbo'],
#  ['Chibab', 'Pepsi'],
#  ['Pepsi'],
#  ['Sotteock'],
#  ['Teokboki', 'Pepsi'],
#  ['Tera'],
#  ['FriedOdeng', 'Toppings'],
#  ['Chibab', 'Teokboki', 'FriedSquid', 'Kimmari'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Menbo', 'Pepsi'],
#  ['Pepsi'],
#  ['Odengtang', 'Chamisl', 'Cass'],
#  ['Menbo', 'FriedOdeng'],
#  ['Cheeseball', 'CheeseStick'],
#  ['Chibab', 'Gyeranzzim'],
#  ['Coolpeace', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['milkfries', 'Cider'],
#  ['milkfries', 'Hashbrown', 'Pepsi'],
#  ['FriesSet'],
#  ['FriedShrimp', 'Teokboki', 'Hashbrown'],
#  ['Chibab', 'Gyeranzzim', 'Pepsi'],
#  ['FriedShrimp', 'Teokboki', 'Coolpeace'],
#  ['Gyeranzzim'],
#  ['Coolpeace'],
#  ['Pepsi'],
#  ['Chibab'],
#  ['Selfjumeokbab', 'Toppings'],
#  ['Sotteock'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Pepsi', 'Teokboki'],
#  ['SPFries', 'Sotteock'],
#  ['Coolpeace', 'FriedShrimp'],
#  ['Sotteock'],
#  ['milkfries', 'Pepsi'],
#  ['Toppings'],
#  ['Chibab', 'Selfjumeokbab', 'Sotteock', 'Pepsi'],
#  ['SPFries', 'Coolpeace', 'Pepsi'],
#  ['Menbo'],
#  ['Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Cheeseball', 'FriedSquid'],
#  ['Cheeseball'],
#  ['Teokboki', 'Pepsi'],
#  ['Cheeseball'],
#  ['milkfries', 'Menbo', 'Toppings', 'Toppings'],
#  ['Pepsi', 'Crab', 'FriedShrimp'],
#  ['milkfries'],
#  ['miniHotdog'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Menbo'],
#  ['SPFries', 'miniHotdog'],
#  ['Toppings', 'Menbo', 'Coolpeace'],
#  ['Teokboki'],
#  ['Teokboki', 'Pepsi', 'Selfjumeokbab', 'FriedShrimp'],
#  ['OranC', 'Toppings'],
#  ['Crab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace', 'FriedSquid', 'FriedShrimp'],
#  ['Teokboki', 'Pepsi'],
#  ['Cass', 'Teokboki', 'FriedOdeng', 'Pepsi'],
#  ['Coolpeace'],
#  ['Sotteock'],
#  ['Chibab', 'Chibab', 'Coolpeace'],
#  ['Odengtang', 'Yakimandu'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Sotteock', 'Cider', 'Toppings'],
#  ['Pepsi'],
#  ['Teokboki', 'Kimmari', 'Pepsi'],
#  ['Chibab', 'Sotteock'],
#  ['Hashbrown', 'Pepsi', 'Cider'],
#  ['Sotteock', 'Pepsi'],
#  ['Yakimandu', 'Menbo', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Crab', 'Coolpeace', 'Pepsi'],
#  ['Toppings', 'Toppings'],
#  ['Sotteock', 'Hashbrown'],
#  ['Toppings'],
#  ['Toppings'],
#  ['Teokboki', 'Coolpeace', 'Chamisl'],
#  ['Teokboki', 'Pepsi'],
#  ['Menbo', 'Pepsi'],
#  ['milkfries', 'Pepsi'],
#  ['SPFries'],
#  ['OranC'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Chibab'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi', 'Menbo'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab', 'Selfjumeokbab', 'Pepsi', 'Pepsi', 'Teokboki', 'FriedSquid'],
#  ['Cass'],
#  ['Coolpeace'],
#  ['Pepsi'],
#  ['Kimmari', 'Pepsi', 'Coolpeace'],
#  ['Chibab', 'Menbo', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Sotteock', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['Toppings', 'Odengtang'],
#  ['Teokboki', 'miniHotdog', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['OranC', 'Hashbrown', 'Kimmari'],
#  ['Teokboki'],
#  ['Selfjumeokbab'],
#  ['Chibab', 'Coolpeace', 'Teokboki', 'FriedSquid'],
#  ['Pepsi'],
#  ['Teokboki', 'Cider'],
#  ['Chibab', 'Sotteock'],
#  ['Teokboki', 'Selfjumeokbab', 'Hashbrown', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Cider'],
#  ['miniHotdog', 'Teokboki', 'OranC', 'Toppings'],
#  ['Teokboki', 'FriesSet', 'Selfjumeokbab'],
#  ['Teokboki', 'Kimmari', 'Cider'],
#  ['Coolpeace', 'FriedShrimp'],
#  ['Chibab', 'Gyeranzzim', 'Sotteock', 'Coolpeace', 'Coolpeace'],
#  ['Chamisl'],
#  ['FriedSquid', 'Coolpeace'],
#  ['Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Sotteock', 'Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi', 'Selfjumeokbab'],
#  ['Menbo'],
#  ['Crab', 'Coolpeace'],
#  ['Chibab', 'Chibab', 'Coolpeace'],
#  ['Chibab', 'Gyeranzzim', 'Pepsi'],
#  ['Sotteock'],
#  ['Teokboki', 'Sotteock', 'Coolpeace'],
#  ['Sotteock', 'FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi'],
#  ['CheeseStick', 'Sotteock'],
#  ['Hashbrown', 'Pepsi'],
#  ['Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Jinro', 'Teokboki', 'Coolpeace', 'FriedSquid', 'FriedShrimp'],
#  ['Teokboki'],
#  ['OranC'],
#  ['Chibab', 'OranC'],
#  ['Chibab'],
#  ['Teokboki', 'FriedShrimp'],
#  ['Yakimandu'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Pepsi', 'Selfjumeokbab'],
#  ['Water'],
#  ['Chibab', 'Coolpeace'],
#  ['Cheeseball'],
#  ['Sotteock'],
#  ['Cheeseball'],
#  ['Teokboki', 'Toppings', 'Coolpeace'],
#  ['Chibab', 'Teokboki'],
#  ['Teokboki', 'Coolpeace'],
#  ['Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['FriesSet', 'Gyeranzzim', 'milkfries', 'Toppings'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki', 'Kimmari', 'Coolpeace'],
#  ['Pepsi'],
#  ['Teokboki', 'Coolpeace', 'Menbo'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Sotteock', 'Cider'],
#  ['Pepsi'],
#  ['Pepsi'],
#  ['Chibab', 'Coolpeace', 'Chibab'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Kimmari', 'Coolpeace'],
#  ['Cheeseball',
#   'Cheeseball',
#   'Teokboki',
#   'Coolpeace',
#   'Crab',
#   'FriedOdeng',
#   'CheeseStick',
#   'Pepsi'],
#  ['Kimmari'],
#  ['Chibab', 'Pepsi'],
#  ['Kimmari', 'Menbo', 'milkfries'],
#  ['Teokboki', 'Selfjumeokbab', 'Kimmari'],
#  ['Coolpeace', 'Kimmari'],
#  ['Selfjumeokbab'],
#  ['Teokboki', 'Coolpeace'],
#  ['Coolpeace', 'FriesSet', 'Kimmari', 'FriedOdeng'],
#  ['Chibab', 'Hashbrown', 'Pepsi'],
#  ['Hashbrown'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki'],
#  ['Chibab', 'Coolpeace', 'Teokboki'],
#  ['Teokboki', 'Coolpeace'],
#  ['Hashbrown'],
#  ['Odengtang'],
#  ['Selfjumeokbab', 'Menbo', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock'],
#  ['OranC'],
#  ['Coolpeace', 'FriesSet', 'Kimmari', 'FriedOdeng'],
#  ['Chibab', 'Hashbrown', 'Pepsi', 'Coolpeace'],
#  ['Coolpeace', 'Chibab'],
#  ['Chibab', 'OranC'],
#  ['milkfries'],
#  ['Cheeseball'],
#  ['Pepsi'],
#  ['Menbo'],
#  ['Coolpeace', 'Yakimandu', 'miniHotdog', 'Chibab', 'Coolpeace', 'Cider'],
#  ['Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Pepsi', 'FriedOdeng'],
#  ['Pepsi'],
#  ['Teokboki', 'Pepsi', 'Coolpeace'],
#  ['Coolpeace'],
#  ['Teokboki'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace', 'Pepsi'],
#  ['Sotteock'],
#  ['Chibab', 'OranC'],
#  ['Pepsi', 'Teokboki', 'Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Odengtang', 'miniHotdog'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['milkfries', 'Pepsi'],
#  ['Chibab', 'Hashbrown', 'Cider'],
#  ['Toppings'],
#  ['Cider', 'Menbo'],
#  ['FriedShrimp', 'FriedSquid', 'Yakimandu'],
#  ['Coolpeace', 'FriesSet', 'Kimmari', 'FriedOdeng'],
#  ['Chibab'],
#  ['Cheeseball'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi', 'FriedSquid'],
#  ['miniHotdog'],
#  ['Chibab', 'Cider', 'Coolpeace'],
#  ['Hashbrown', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Menbo'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Coolpeace'],
#  ['FriedSquid', 'Coolpeace', 'miniHotdog'],
#  ['Chibab'],
#  ['Pepsi', 'FriedSquid', 'Coolpeace'],
#  ['Crab'],
#  ['Teokboki', 'Coolpeace'],
#  ['milkfries', 'FriedShrimp'],
#  ['Chibab', 'miniHotdog'],
#  ['Sotteock', 'Pepsi', 'Teokboki'],
#  ['Chibab', 'Pepsi'],
#  ['Cider'],
#  ['Chibab'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Gyeranzzim', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock', 'Teokboki'],
#  ['FriedShrimp', 'Hashbrown'],
#  ['Teokboki'],
#  ['Teokboki', 'Hashbrown', 'milkfries', 'Coolpeace'],
#  ['Chamisl', 'milkfries'],
#  ['Chibab', 'SPFries', 'Cider'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Selfjumeokbab', 'Coolpeace'],
#  ['Crab', 'Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Toppings', 'Pepsi', 'Jinro'],
#  ['Menbo', 'FriedShrimp'],
#  ['Chibab', 'Pepsi', 'Pepsi'],
#  ['milkfries'],
#  ['Sotteock', 'Coolpeace'],
#  ['Chibab', 'SPFries'],
#  ['Chibab', 'Coolpeace'],
#  ['Chamisl'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Toppings', 'Pepsi'],
#  ['Toppings'],
#  ['Chibab', 'Pepsi', 'Chibab'],
#  ['Toppings'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Selfjumeokbab', 'SPFries', 'Menbo', 'FriedShrimp'],
#  ['Chibab', 'Coolpeace', 'Chibab', 'FriesSet', 'Teokboki'],
#  ['Cheeseball', 'Pepsi'],
#  ['Chibab',
#   'Kimmari',
#   'SPFries',
#   'Teokboki',
#   'Coolpeace',
#   'Chibab',
#   'Hashbrown'],
#  ['Chibab', 'milkfries', 'Coolpeace', 'Coolpeace'],
#  ['Toppings', 'Coolpeace', 'FriedShrimp'],
#  ['Pepsi'],
#  ['Teokboki', 'milkfries', 'Pepsi'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki'],
#  ['Chibab', 'Coolpeace'],
#  ['FriedSquid', 'Teokboki', 'Kimmari'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki'],
#  ['Chibab', 'Selfjumeokbab', 'Coolpeace', 'Teokboki', 'Chibab'],
#  ['Chibab'],
#  ['Yakimandu', 'miniHotdog', 'Pepsi'],
#  ['miniHotdog', 'FriedOdeng', 'Hashbrown'],
#  ['Pepsi'],
#  ['miniHotdog', 'Pepsi'],
#  ['Teokboki', 'milkfries'],
#  ['Coolpeace', 'Menbo', 'milkfries'],
#  ['milkfries'],
#  ['Teokboki', 'Selfjumeokbab', 'Sotteock', 'OranC'],
#  ['Sotteock', 'Menbo'],
#  ['miniHotdog', 'Coolpeace', 'Teokboki'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi'],
#  ['Toppings', 'Coolpeace', 'Cheeseball'],
#  ['Toppings', 'Pepsi', 'FriedShrimp'],
#  ['Chibab', 'Toppings', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Menbo'],
#  ['Teokboki', 'Pepsi'],
#  ['Menbo', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki', 'Pepsi', 'Coolpeace'],
#  ['Chibab', 'Pepsi', 'Coolpeace', 'Hashbrown'],
#  ['Pepsi', 'Selfjumeokbab', 'Sotteock'],
#  ['Menbo', 'Sotteock'],
#  ['Coolpeace', 'Yakimandu', 'miniHotdog'],
#  ['FriesSet', 'Kimmari', 'FriedOdeng', 'Pepsi'],
#  ['Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['miniHotdog', 'Pepsi'],
#  ['milkfries', 'Menbo', 'Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Pepsi', 'Menbo'],
#  ['Hashbrown', 'Menbo'],
#  ['Cider', 'Odengtang'],
#  ['Yakimandu', 'FriedSquid'],
#  ['Menbo'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace', 'Coolpeace'],
#  ['Teokboki', 'Kimmari'],
#  ['Cheeseball'],
#  ['Cider'],
#  ['Chibab', 'Pepsi'],
#  ['Pepsi'],
#  ['Pepsi'],
#  ['miniHotdog', 'milkfries'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock', 'Sotteock'],
#  ['Cheeseball', 'miniHotdog'],
#  ['Chibab'],
#  ['Toppings', 'Teokboki'],
#  ['Menbo'],
#  ['Chibab', 'Hashbrown', 'Toppings', 'Coolpeace'],
#  ['Chibab', 'Selfjumeokbab', 'Coolpeace', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['Cider'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['miniHotdog', 'milkfries'],
#  ['Hashbrown', 'miniHotdog'],
#  ['Toppings', 'FriedSquid', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['FriedSquid', 'Teokboki', 'FriedOdeng', 'Odengtang'],
#  ['Chibab', 'Cider', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['miniHotdog', 'Teokboki'],
#  ['Chibab', 'Coolpeace', 'Coolpeace'],
#  ['Cheeseball'],
#  ['Teokboki', 'Coolpeace'],
#  ['FriedShrimp'],
#  ['Teokboki', 'Coolpeace'],
#  ['Cheeseball'],
#  ['Toppings'],
#  ['Chibab', 'Pepsi'],
#  ['Coolpeace', 'Yakimandu', 'miniHotdog'],
#  ['Toppings', 'Teokboki'],
#  ['Menbo', 'Toppings'],
#  ['Chibab'],
#  ['Toppings', 'Toppings'],
#  ['Sotteock', 'Toppings']]

# %%
# apriori 알고리즘
from mlxtend.frequent_patterns import apriori, association_rules
# 연관분석용 데이터 파일 변환
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import matplotlib.pyplot as plt

# %%
te = TransactionEncoder()
ted = te.fit(basket).transform(basket)
ted
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df = pd.DataFrame(ted, columns=te.columns_)
df
# Out:
#       Cass  Chamisl  CheeseStick  Cheeseball  Chibab  Cider  Coolpeace   Crab  \
# 0    False    False        False       False   False  False      False  False
# 1    False    False        False       False    True  False      False  False
# 2    False    False        False       False   False  False      False  False
# 3    False    False        False       False    True  False      False  False
# 4    False    False        False       False   False  False      False  False
# ..     ...      ...          ...         ...     ...    ...        ...    ...
# 443  False    False        False       False   False  False      False  False
# 444  False    False        False       False   False  False      False  False
# 445  False    False        False       False    True  False      False  False
# 446  False    False        False       False   False  False      False  False
# 447  False    False        False       False   False  False      False  False
#
#      FriedOdeng  FriedShrimp  ...  SPFries  Selfjumeokbab  Sotteock  Teokboki  \
# 0         False        False  ...    False          False     False     False
# 1         False        False  ...    False          False     False      True
# 2         False        False  ...    False          False      True     False
# 3         False        False  ...    False          False     False     False
# 4         False        False  ...    False          False     False     False
# ..          ...          ...  ...      ...            ...       ...       ...
# 443       False        False  ...    False          False     False      True
# 444       False        False  ...    False          False     False     False
# 445       False        False  ...    False          False     False     False
# 446       False        False  ...    False          False     False     False
# 447       False        False  ...    False          False      True     False
#
#       Tera  Toppings  Water  Yakimandu  milkfries  miniHotdog
# 0    False     False  False      False      False       False
# 1    False     False  False      False      False       False
# 2    False     False  False      False      False       False
# 3    False     False  False      False      False       False
# 4    False     False  False      False      False       False
# ..     ...       ...    ...        ...        ...         ...
# 443  False      True  False      False      False       False
# 444  False      True  False      False      False       False
# 445  False     False  False      False      False       False
# 446  False      True  False      False      False       False
# 447  False      True  False      False      False       False
#
# [448 rows x 30 columns]

# %% [markdown]
# ## 2. 탐색적 데이터 분석

# %%
freq = df.sum().to_frame('Frequency')
freq_sort = freq.sort_values('Frequency', ascending = False)
print(freq_sort)
# Out:
#                Frequency
# Coolpeace            147
# Chibab               137
# Pepsi                123
# Teokboki             104
# Sotteock              48
# Menbo                 37
# Toppings              36
# FriedShrimp           24
# Hashbrown             23
# milkfries             23
# Selfjumeokbab         22
# miniHotdog            21
# FriedSquid            20
# Kimmari               19
# Cider                 18
# Cheeseball            16
# OranC                 11
# FriedOdeng            11
# FriesSet              10
# Odengtang              9
# SPFries                9
# Yakimandu              9
# Gyeranzzim             8
# Crab                   8
# Chamisl                6
# CheeseStick            6
# Jinro                  3
# Cass                   3
# Tera                   1
# Water                  1

# %%
freq_sort['Support'] = freq_sort['Frequency'] / len(df)
print(freq_sort)
# Out:
#                Frequency   Support
# Coolpeace            147  0.328125
# Chibab               137  0.305804
# Pepsi                123  0.274554
# Teokboki             104  0.232143
# Sotteock              48  0.107143
# Menbo                 37  0.082589
# Toppings              36  0.080357
# FriedShrimp           24  0.053571
# Hashbrown             23  0.051339
# milkfries             23  0.051339
# Selfjumeokbab         22  0.049107
# miniHotdog            21  0.046875
# FriedSquid            20  0.044643
# Kimmari               19  0.042411
# Cider                 18  0.040179
# Cheeseball            16  0.035714
# OranC                 11  0.024554
# FriedOdeng            11  0.024554
# FriesSet              10  0.022321
# Odengtang              9  0.020089
# SPFries                9  0.020089
# Yakimandu              9  0.020089
# Gyeranzzim             8  0.017857
# Crab                   8  0.017857
# Chamisl                6  0.013393
# CheeseStick            6  0.013393
# Jinro                  3  0.006696
# Cass                   3  0.006696
# Tera                   1  0.002232
# Water                  1  0.002232

# %%
freq_sort['Frequency'].plot(kind='bar', title='FrequentItems');

# %%
freq_sort['Support'].hist();

# %% [markdown]
# ## 3. 연관규칙 생성

# %%
freq_items = apriori(df, min_support=0.01, use_colnames=True)
print(freq_items)
# Out:
#      support                       itemsets
# 0   0.013393                      (Chamisl)
# 1   0.013393                  (CheeseStick)
# 2   0.035714                   (Cheeseball)
# 3   0.305804                       (Chibab)
# 4   0.040179                        (Cider)
# ..       ...                            ...
# 57  0.015625      (Teokboki, Selfjumeokbab)
# 58  0.017857           (Sotteock, Teokboki)
# 59  0.011161           (Teokboki, Toppings)
# 60  0.011161         (Teokboki, miniHotdog)
# 61  0.011161  (Teokboki, Coolpeace, Chibab)
#
# [62 rows x 2 columns]

# %%
rules = association_rules(freq_items, metric = 'confidence', min_threshold = 0.5)

rules
# Out:
#           antecedents  consequents  antecedent support  consequent support  \
# 0        (Gyeranzzim)     (Chibab)            0.017857            0.305804
# 1              (Crab)      (Pepsi)            0.017857            0.274554
# 2           (Kimmari)   (Teokboki)            0.042411            0.232143
# 3  (Teokboki, Chibab)  (Coolpeace)            0.022321            0.328125
#
#     support  confidence      lift  leverage  conviction
# 0  0.011161    0.625000  2.043796  0.005700    1.851190
# 1  0.011161    0.625000  2.276423  0.006258    1.934524
# 2  0.022321    0.526316  2.267206  0.012476    1.621032
# 3  0.011161    0.500000  1.523810  0.003836    1.343750

# %%
rules = rules[(rules['lift'] > 1)]
rules.sort_values(by = 'confidence', ascending = False)
# Out:
#           antecedents  consequents  antecedent support  consequent support  \
# 0        (Gyeranzzim)     (Chibab)            0.017857            0.305804
# 1              (Crab)      (Pepsi)            0.017857            0.274554
# 2           (Kimmari)   (Teokboki)            0.042411            0.232143
# 3  (Teokboki, Chibab)  (Coolpeace)            0.022321            0.328125
#
#     support  confidence      lift  leverage  conviction
# 0  0.011161    0.625000  2.043796  0.005700    1.851190
# 1  0.011161    0.625000  2.276423  0.006258    1.934524
# 2  0.022321    0.526316  2.267206  0.012476    1.621032
# 3  0.011161    0.500000  1.523810  0.003836    1.343750

# %% [markdown]
# - 조건부에 '치밥'이 있는 규칙

# %%
rules[rules.antecedents.apply(lambda x:'Chibab' in x)]
# Out:
#           antecedents  consequents  antecedent support  consequent support  \
# 3  (Teokboki, Chibab)  (Coolpeace)            0.022321            0.328125
#
#     support  confidence     lift  leverage  conviction
# 3  0.011161         0.5  1.52381  0.003836     1.34375

# %%
rules[rules.antecedents.apply(lambda x:'Gyeranzzim' in x)]
# Out:
#     antecedents consequents  antecedent support  consequent support   support  \
# 0  (Gyeranzzim)    (Chibab)            0.017857            0.305804  0.011161
#
#    confidence      lift  leverage  conviction
# 0       0.625  2.043796    0.0057     1.85119

# %% [markdown]
# - 결론구에 '치밥'이 있는 규칙

# %%
rules[rules.consequents.apply(lambda x:'Chibab' in x)]
# Out:
#     antecedents consequents  antecedent support  consequent support   support  \
# 0  (Gyeranzzim)    (Chibab)            0.017857            0.305804  0.011161
#
#    confidence      lift  leverage  conviction
# 0       0.625  2.043796    0.0057     1.85119
