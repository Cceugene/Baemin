# %%
import pandas as pd
import numpy as np

# %%
import pickle
with open('Tako_menus.pkl', 'rb') as f:
    data = pickle.load(f)

# %% [markdown]
# # 데이터 정제

# %% [markdown]
# 값이 없는 키 삭제

# %%
data.pop(574)
data
# Out:
# {1: ['2022. 05. 16. (월)\n오후 08:50:22',
#   '배달',
#   '이연X의멘보샤(특제소스제공)\n2개',
#   '┗ 4개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  2: ['2022. 05. 16. (월)\n오후 08:43:26',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  3: ['2022. 05. 16. (월)\n오후 06:58:21',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  4: ['2022. 05. 16. (월)\n오후 06:16:13',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 매콤양념치킨',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  5: ['2022. 05. 16. (월)\n오후 05:42:10',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  6: ['2022. 05. 16. (월)\n오후 12:12:47',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  7: ['2022. 05. 16. (월)\n오전 11:58:58',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  8: ['2022. 05. 16. (월)\n오전 11:55:47',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 모듬튀김 8개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  9: ['2022. 05. 16. (월)\n오전 10:46:49',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  10: ['2022. 05. 15. (일)\n오후 10:18:27',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 우유튀김 5개',
#   '┗ 오징어튀김 2개',
#   '┗ 매콤양념 (맛선택)'],
#  11: ['2022. 05. 15. (일)\n오후 10:17:26',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 고구마튀김 4개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  12: ['2022. 05. 15. (일)\n오후 09:28:32',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본'],
#  13: ['2022. 05. 15. (일)\n오후 09:11:04',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  14: ['2022. 05. 15. (일)\n오후 09:02:47',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  15: ['2022. 05. 15. (일)\n오후 08:32:03',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 매콤양념 (맛선택)'],
#  16: ['2022. 05. 15. (일)\n오후 07:53:36',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  17: ['2022. 05. 15. (일)\n오후 07:09:28',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 약한맛',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)'],
#  18: ['2022. 05. 15. (일)\n오후 02:44:02',
#   '배달',
#   '해쉬브라운\n1개',
#   '┗ 2개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  19: ['2022. 05. 15. (일)\n오전 10:53:16',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  20: ['2022. 05. 14. (토)\n오후 10:20:09',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '게맛살튀김\n1개',
#   '┗ 3개',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  21: ['2022. 05. 14. (토)\n오후 09:49:19',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양고추 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  22: ['2022. 05. 14. (토)\n오후 09:27:48',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 왕오징어튀김 3개',
#   '┗ 오리지널 (맛선택)'],
#  23: ['2022. 05. 14. (토)\n오후 09:14:21',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  24: ['2022. 05. 14. (토)\n오후 08:37:59',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '볶음김치마요 셀프주먹밥\n1개',
#   '┗ 기본',
#   '계란찜\n1개',
#   '┗ 기본'],
#  25: ['2022. 05. 14. (토)\n오후 06:19:59',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  26: ['2022. 05. 14. (토)\n오후 05:14:24',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  27: ['2022. 05. 14. (토)\n오전 11:48:07',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  28: ['2022. 05. 14. (토)\n오전 10:37:12',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 청양마요 (맛선택)'],
#  29: ['2022. 05. 13. (금)\n오후 09:46:15',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 소떡소떡 1개',
#   '┗ 오징어튀김 2개',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  30: ['2022. 05. 13. (금)\n오후 08:35:39',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 오리지널 (맛선택)'],
#  31: ['2022. 05. 13. (금)\n오후 07:27:12',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  32: ['2022. 05. 13. (금)\n오후 06:55:11',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개'],
#  33: ['2022. 05. 13. (금)\n오전 11:47:28',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '날치알마요 셀프주먹밥\n1개',
#   '┗ 기본'],
#  34: ['2022. 05. 12. (목)\n오후 08:50:34',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '쿨피스 캔\n2개',
#   '┗ 350ml'],
#  35: ['2022. 05. 12. (목)\n오후 08:10:19',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 소떡소떡 1개',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  36: ['2022. 05. 12. (목)\n오후 05:17:55',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  37: ['2022. 05. 12. (목)\n오후 02:36:16',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  38: ['2022. 05. 10. (화)\n오후 09:30:45',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  39: ['2022. 05. 10. (화)\n오후 08:04:14',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 안매운양념 (맛선택)'],
#  40: ['2022. 05. 10. (화)\n오후 05:44:58',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 치즈스틱 5개',
#   '┗ 쿨피스 350ml'],
#  41: ['2022. 05. 10. (화)\n오후 05:13:17',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈스틱 5개',
#   '┗ 파마산치즈+청양마요 (토핑추가)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  42: ['2022. 05. 10. (화)\n오후 02:37:28',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 매콤 마늘간장',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  43: ['2022. 05. 10. (화)\n오후 12:39:38',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 펩시콜라 355ml',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)'],
#  44: ['2022. 05. 09. (월)\n오후 10:17:18',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  45: ['2022. 05. 09. (월)\n오후 10:06:45',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  46: ['2022. 05. 09. (월)\n오후 09:54:04',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 펩시콜라 1.25L',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  47: ['2022. 05. 09. (월)\n오후 09:01:08',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  48: ['2022. 05. 09. (월)\n오후 03:19:18',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  49: ['2022. 05. 09. (월)\n오후 02:33:51',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 콜라 355ml 추가',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  50: ['2022. 05. 09. (월)\n오후 01:16:23',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 청양고추+오리지널 (맛선택)'],
#  51: ['2022. 05. 09. (월)\n오후 01:07:23',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  52: ['2022. 05. 09. (월)\n오후 12:58:56',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml',
#   '┗ 안매운양념 (맛선택)'],
#  53: ['2022. 05. 08. (일)\n오후 09:30:36',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 펩시콜라 1.25L',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  54: ['2022. 05. 08. (일)\n오후 07:21:38',
#   '배달',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '소떡소떡\n2개',
#   '┗ 1개',
#   '치즈볼 4개\n1개',
#   '┗ 기본'],
#  55: ['2022. 05. 08. (일)\n오후 05:46:44',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml'],
#  56: ['2022. 05. 08. (일)\n오후 02:31:27',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화 바베큐'],
#  57: ['2022. 05. 08. (일)\n오후 12:59:53',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  58: ['2022. 05. 08. (일)\n오후 12:37:40',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '오란씨(파인맛)\n1개',
#   '┗ 1.5L'],
#  59: ['2022. 05. 08. (일)\n오전 11:21:48',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  60: ['2022. 05. 07. (토)\n오후 08:24:32',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  61: ['2022. 05. 07. (토)\n오후 08:19:57',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  62: ['2022. 05. 07. (토)\n오후 08:14:36',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 모듬튀김 8개',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  63: ['2022. 05. 07. (토)\n오후 06:39:32',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개',
#   '소떡소떡\n1개',
#   '┗ 1개',
#   '사이다\n1개',
#   '┗ 355ml',
#   '치즈스틱 5개\n1개',
#   '┗ 기본'],
#  64: ['2022. 05. 07. (토)\n오후 06:29:03',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 해쉬브라운 2개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 양념치킨'],
#  65: ['2022. 05. 07. (토)\n오후 06:00:58',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  66: ['2022. 05. 07. (토)\n오후 02:18:18',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  67: ['2022. 05. 07. (토)\n오후 01:06:49',
#   '배달',
#   '진로 이즈벡\n2개',
#   '┗ 기본',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 약한맛',
#   '미니오뎅탕\n1개',
#   '┗ 기본',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  68: ['2022. 05. 07. (토)\n오전 11:23:07',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  69: ['2022. 05. 07. (토)\n오전 11:12:43',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 매콤양념 (맛선택)'],
#  70: ['2022. 05. 06. (금)\n오후 09:51:03',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  71: ['2022. 05. 06. (금)\n오후 09:41:50',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  72: ['2022. 05. 06. (금)\n오후 09:17:36',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 갈비천왕',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml'],
#  73: ['2022. 05. 06. (금)\n오후 08:56:05',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  74: ['2022. 05. 06. (금)\n오후 08:09:08',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛'],
#  75: ['2022. 05. 06. (금)\n오후 07:08:00',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 콜라 355ml 추가',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  76: ['2022. 05. 05. (목)\n오후 09:46:20',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  77: ['2022. 05. 05. (목)\n오후 09:45:26',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  78: ['2022. 05. 05. (목)\n오후 09:38:49',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 이연x멘보샤 3개(특제소스 제공)'],
#  79: ['2022. 05. 05. (목)\n오후 09:03:48',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  80: ['2022. 05. 05. (목)\n오후 07:57:54',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '치즈볼 4개\n1개',
#   '┗ 기본'],
#  81: ['2022. 05. 05. (목)\n오후 03:12:01',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 소떡소떡 1개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  82: ['2022. 05. 03. (화)\n오후 10:16:10',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛'],
#  83: ['2022. 05. 03. (화)\n오후 10:04:03',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '테라\n1개',
#   '┗ 병'],
#  84: ['2022. 05. 03. (화)\n오후 09:58:30',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  85: ['2022. 05. 03. (화)\n오후 09:38:00',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  86: ['2022. 05. 03. (화)\n오후 09:04:30',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오뎅튀김 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  87: ['2022. 05. 03. (화)\n오후 06:43:56',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 양념치킨',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  88: ['2022. 05. 03. (화)\n오후 01:53:10',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  89: ['2022. 05. 03. (화)\n오후 01:12:17',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛'],
#  90: ['2022. 05. 03. (화)\n오후 01:00:28',
#   '배달',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)'],
#  91: ['2022. 05. 02. (월)\n오후 07:40:06',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  92: ['2022. 05. 02. (월)\n오후 05:08:13',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 안매운양념 (맛선택)'],
#  93: ['2022. 05. 02. (월)\n오후 01:29:48',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n2개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  94: ['2022. 05. 02. (월)\n오전 11:40:56',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  95: ['2022. 05. 01. (일)\n오후 09:06:40',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  96: ['2022. 05. 01. (일)\n오후 09:01:08',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  97: ['2022. 05. 01. (일)\n오후 08:26:01',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  98: ['2022. 05. 01. (일)\n오후 08:02:34',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  99: ['2022. 05. 01. (일)\n오후 07:51:43',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  100: ['2022. 05. 01. (일)\n오후 07:46:41',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '미니오뎅탕\n1개',
#   '┗ 기본',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본',
#   '카스\n1개',
#   '┗ 병'],
#  101: ['2022. 05. 01. (일)\n오후 06:58:19',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오뎅튀김 6개',
#   '┗ 가쓰오부시 추가',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  102: ['2022. 05. 01. (일)\n오후 06:51:03',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  103: ['2022. 05. 01. (일)\n오후 06:06:10',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 치즈스틱 5개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  104: ['2022. 05. 01. (일)\n오후 05:54:37',
#   '배달',
#   '치밥 도시락\n4개',
#   '┗ 기본',
#   '┗ 계란찜',
#   '┗ 갈비천왕'],
#  105: ['2022. 05. 01. (일)\n오후 05:30:49',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '쿨피스 캔\n1개',
#   '┗ 350ml'],
#  106: ['2022. 05. 01. (일)\n오후 01:10:40',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)'],
#  107: ['2022. 05. 01. (일)\n오후 12:03:55',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  108: ['2022. 04. 30. (토)\n오후 10:28:58',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  109: ['2022. 04. 30. (토)\n오후 09:09:36',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '우유튀김 6개\n1개',
#   '┗ 기본',
#   '사이다\n1개',
#   '┗ 355ml'],
#  110: ['2022. 04. 30. (토)\n오후 08:17:23',
#   '배달',
#   '우유튀김 6개\n1개',
#   '┗ 기본',
#   '해쉬브라운\n1개',
#   '┗ 2개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 500ml'],
#  111: ['2022. 04. 30. (토)\n오후 06:48:27',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 모듬튀김 8개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  112: ['2022. 04. 30. (토)\n오후 06:15:13',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '해쉬브라운\n1개',
#   '┗ 2개'],
#  113: ['2022. 04. 30. (토)\n오후 02:55:13',
#   '배달',
#   '치밥 도시락\n4개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '계란찜\n1개',
#   '┗ 기본',
#   '펩시콜라\n4개',
#   '┗ 355ml'],
#  114: ['2022. 04. 29. (금)\n오후 09:33:01',
#   '배달',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 중간맛',
#   '┗ 쿨피스 350ml'],
#  115: ['2022. 04. 29. (금)\n오후 09:27:25',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '계란찜\n4개',
#   '┗ 기본',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 가쓰오부시 추가',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  116: ['2022. 04. 29. (금)\n오후 08:34:06',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 가쓰오부시 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  117: ['2022. 04. 29. (금)\n오후 07:57:46',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 500ml'],
#  118: ['2022. 04. 29. (금)\n오후 06:23:24',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 마늘간장'],
#  119: ['2022. 04. 29. (금)\n오후 05:36:28',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 청양고추 (토핑추가)',
#   '┗ 오리지널 (맛선택)'],
#  120: ['2022. 04. 29. (금)\n오후 12:56:27',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 1.25L 추가',
#   '┗ 소떡소떡 1개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  121: ['2022. 04. 29. (금)\n오후 12:00:39',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)'],
#  122: ['2022. 04. 29. (금)\n오전 11:43:04',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양고추+오리지널 (맛선택)'],
#  123: ['2022. 04. 28. (목)\n오후 08:24:13',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  124: ['2022. 04. 28. (목)\n오후 08:10:44',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 고구마튀김 4개',
#   '┗ 치즈볼 4개',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)'],
#  125: ['2022. 04. 28. (목)\n오후 01:34:21',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 15cm왕새우튀김 3개'],
#  126: ['2022. 04. 28. (목)\n오후 12:04:12',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 콜라 500ml 추가',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  127: ['2022. 04. 28. (목)\n오전 11:01:26',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 우유튀김 5개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)'],
#  128: ['2022. 04. 28. (목)\n오전 10:51:23',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 15cm새우튀김 2개',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)'],
#  129: ['2022. 04. 26. (화)\n오후 10:22:55',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 소떡소떡 1개',
#   '┗ 펩시콜라 500ml',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  130: ['2022. 04. 26. (화)\n오후 09:04:33',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 고구마튀김 4개',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  131: ['2022. 04. 26. (화)\n오후 08:07:36',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  132: ['2022. 04. 26. (화)\n오후 06:57:43',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 치즈볼 4개'],
#  133: ['2022. 04. 26. (화)\n오후 02:01:02',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  134: ['2022. 04. 26. (화)\n오후 01:28:58',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)'],
#  135: ['2022. 04. 26. (화)\n오후 12:51:47',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양마요 (맛선택)',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml'],
#  136: ['2022. 04. 26. (화)\n오전 11:00:09',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  137: ['2022. 04. 25. (월)\n오후 09:51:20',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '허니버터 치즈볼 4개\n1개',
#   '┗ 기본',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  138: ['2022. 04. 25. (월)\n오후 09:27:51',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  139: ['2022. 04. 25. (월)\n오후 09:24:52',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 스노윙 치즈볼 4개',
#   '┗ 콜라 1.25L 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  140: ['2022. 04. 25. (월)\n오후 08:58:26',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  141: ['2022. 04. 25. (월)\n오후 05:35:37',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 콜라 355ml 추가',
#   '┗ 오리지널 (맛선택)'],
#  142: ['2022. 04. 25. (월)\n오후 03:15:54',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  143: ['2022. 04. 25. (월)\n오후 02:20:13',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  144: ['2022. 04. 25. (월)\n오후 01:56:49',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 스노윙 치즈볼 4개',
#   '┗ 오징어튀김 2개',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  145: ['2022. 04. 25. (월)\n오후 12:26:17',
#   '배달',
#   '우유튀김 6개\n1개',
#   '┗ 기본',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+청양마요 (토핑추가)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  146: ['2022. 04. 24. (일)\n오후 02:41:11',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양마요 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 게맛살 튀김3개',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  147: ['2022. 04. 24. (일)\n오전 11:35:47',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 우유튀김 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  148: ['2022. 04. 24. (일)\n오전 11:09:01',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  149: ['2022. 04. 24. (일)\n오전 10:53:41',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  150: ['2022. 04. 23. (토)\n오후 10:10:50',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 한입핫도그 6개',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  151: ['2022. 04. 23. (토)\n오후 09:55:12',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  152: ['2022. 04. 23. (토)\n오후 08:35:02',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  153: ['2022. 04. 23. (토)\n오후 07:52:49',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 갈비천왕'],
#  154: ['2022. 04. 23. (토)\n오후 07:24:06',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  155: ['2022. 04. 23. (토)\n오후 06:32:20',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)'],
#  156: ['2022. 04. 23. (토)\n오후 05:45:39',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  157: ['2022. 04. 23. (토)\n오후 02:19:27',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '고구마튀김 4개\n1개',
#   '┗ 기본',
#   '한입핫도그 5개\n1개',
#   '┗ 기본'],
#  158: ['2022. 04. 23. (토)\n오전 11:54:41',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추 (토핑추가)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  159: ['2022. 04. 22. (금)\n오후 10:23:20',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  160: ['2022. 04. 22. (금)\n오후 10:17:43',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 중간맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '날치알마요 셀프주먹밥\n1개',
#   '┗ 기본',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  161: ['2022. 04. 22. (금)\n오후 10:13:34',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오란씨(파인맛) 500ml',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  162: ['2022. 04. 22. (금)\n오후 09:21:35',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  163: ['2022. 04. 22. (금)\n오후 08:42:22',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '게맛살튀김\n1개',
#   '┗ 3개',
#   '펩시콜라\n1개',
#   '┗ 1.25L'],
#  164: ['2022. 04. 22. (금)\n오후 08:41:36',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  165: ['2022. 04. 22. (금)\n오후 07:27:50',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)'],
#  166: ['2022. 04. 22. (금)\n오후 07:15:42',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  167: ['2022. 04. 22. (금)\n오후 06:44:41',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  168: ['2022. 04. 22. (금)\n오후 06:26:34',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛'],
#  169: ['2022. 04. 21. (목)\n오후 10:05:50',
#   '배달',
#   '카스\n1개',
#   '┗ 병',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오뎅튀김 6개',
#   '┗ 펩시콜라 355ml',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)'],
#  170: ['2022. 04. 21. (목)\n오후 09:21:33',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 치즈볼 4개'],
#  171: ['2022. 04. 21. (목)\n오후 09:10:27',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 24알 추가 (총 36알)',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  172: ['2022. 04. 21. (목)\n오후 08:09:24',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n2개',
#   '┗ 1개'],
#  173: ['2022. 04. 21. (목)\n오후 05:20:40',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  174: ['2022. 04. 21. (목)\n오전 11:30:08',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '미니오뎅탕\n1개',
#   '┗ 기본',
#   '야끼만두 5개\n1개',
#   '┗ 기본'],
#  175: ['2022. 04. 19. (화)\n오후 06:45:30',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 15cm왕새우튀김 3개',
#   '┗ 펩시콜라 355ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  176: ['2022. 04. 19. (화)\n오후 05:41:03',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 사이다 500ml',
#   '┗ 대파+파마산치즈 (토핑추가)',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화 바베큐'],
#  177: ['2022. 04. 19. (화)\n오후 05:22:02',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  178: ['2022. 04. 19. (화)\n오후 03:17:35',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 김말이 4개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 약한맛'],
#  179: ['2022. 04. 19. (화)\n오후 01:32:24',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 소떡소떡 1개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  180: ['2022. 04. 19. (화)\n오전 11:28:56',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  181: ['2022. 04. 19. (화)\n오전 11:12:13',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  182: ['2022. 04. 19. (화)\n오전 10:58:51',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '해쉬브라운\n1개',
#   '┗ 4개',
#   '펩시콜라\n1개',
#   '┗ 1.25L',
#   '사이다\n1개',
#   '┗ 1.25L'],
#  183: ['2022. 04. 18. (월)\n오후 10:25:32',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n1개',
#   '┗ 1개',
#   '펩시콜라\n1개',
#   '┗ 355ml'],
#  184: ['2022. 04. 18. (월)\n오후 09:48:07',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  185: ['2022. 04. 18. (월)\n오후 09:27:30',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 야끼만두 5개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 쿨피스 350ml'],
#  186: ['2022. 04. 18. (월)\n오후 07:28:19',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 24알 추가 (총 36알)',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 가쓰오부시 추가',
#   '┗ 갈비천왕',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  187: ['2022. 04. 18. (월)\n오후 06:56:34',
#   '배달',
#   '게맛살튀김\n1개',
#   '┗ 3개',
#   '쿨피스 캔\n1개',
#   '┗ 350ml',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  188: ['2022. 04. 18. (월)\n오후 06:14:43',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 가쓰오부시 추가',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 가쓰오부시 추가',
#   '┗ 대파 (토핑추가)',
#   '┗ 안매운양념 (맛선택)'],
#  189: ['2022. 04. 18. (월)\n오후 02:03:05',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  190: ['2022. 04. 18. (월)\n오후 01:05:09',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  191: ['2022. 04. 18. (월)\n오후 12:57:45',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 소떡소떡 1개',
#   '┗ 해쉬브라운 2개',
#   '┗ 오리지널 (맛선택)'],
#  192: ['2022. 04. 18. (월)\n오전 11:29:36',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  193: ['2022. 04. 17. (일)\n오후 10:16:48',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 대파 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  194: ['2022. 04. 17. (일)\n오후 08:30:26',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본'],
#  195: ['2022. 04. 17. (일)\n오후 08:09:42',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛'],
#  196: ['2022. 04. 17. (일)\n오후 07:48:22',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)'],
#  197: ['2022. 04. 17. (일)\n오후 07:20:33',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 우유튀김 6개',
#   '┗ 펩시콜라 355ml'],
#  198: ['2022. 04. 17. (일)\n오후 06:25:16',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 고구마튀김 4개',
#   '┗ 콜라 1.25L 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  199: ['2022. 04. 17. (일)\n오후 06:00:34',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 오란씨(파인맛) 1.5L',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  200: ['2022. 04. 17. (일)\n오후 02:15:59',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '수제 등심돈까스\n1개',
#   '┗ 기본'],
#  201: ['2022. 04. 17. (일)\n오후 01:07:26',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 양념치킨',
#   '┗ 쿨피스 350ml'],
#  202: ['2022. 04. 17. (일)\n오전 11:30:05',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  203: ['2022. 04. 16. (토)\n오후 09:21:50',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  204: ['2022. 04. 16. (토)\n오후 09:19:43',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  205: ['2022. 04. 16. (토)\n오후 09:13:25',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 15cm새우튀김 2개',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  206: ['2022. 04. 16. (토)\n오후 09:12:35',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  207: ['2022. 04. 16. (토)\n오후 07:42:54',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 1.25L',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)'],
#  208: ['2022. 04. 16. (토)\n오후 05:25:29',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)'],
#  209: ['2022. 04. 16. (토)\n오후 01:55:34',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 가쓰오부시 추가',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  210: ['2022. 04. 15. (금)\n오후 10:19:04',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 매콤양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  211: ['2022. 04. 14. (목)\n오후 10:12:59',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '카스\n1개',
#   '┗ 병'],
#  212: ['2022. 04. 14. (목)\n오후 08:56:22',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 매콤양념 (맛선택)'],
#  213: ['2022. 04. 14. (목)\n오후 06:20:57',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 오징어튀김 2개',
#   '┗ 매콤양념 (맛선택)'],
#  214: ['2022. 04. 14. (목)\n오후 05:35:53',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 매콤양념 (맛선택)'],
#  215: ['2022. 04. 14. (목)\n오후 03:16:01',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 찰김말이 6개',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 쿨피스 350ml'],
#  216: ['2022. 04. 14. (목)\n오후 12:23:05',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 가쓰오부시 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  217: ['2022. 04. 14. (목)\n오전 11:39:34',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 약한맛'],
#  218: ['2022. 04. 12. (화)\n오후 07:47:37',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  219: ['2022. 04. 12. (화)\n오후 07:40:11',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '┗ 펩시콜라 355ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  220: ['2022. 04. 12. (화)\n오후 06:42:52',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파 (토핑추가)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  221: ['2022. 04. 12. (화)\n오후 06:13:58',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)'],
#  222: ['2022. 04. 12. (화)\n오후 05:47:30',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 한입핫도그 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 쿨피스 350ml',
#   '┗ 강한맛',
#   '┗ 오리지널 (맛선택)'],
#  223: ['2022. 04. 12. (화)\n오후 03:06:34',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml'],
#  224: ['2022. 04. 12. (화)\n오후 01:07:45',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '오란씨(파인맛)\n1개',
#   '┗ 1.5L',
#   '해쉬브라운\n1개',
#   '┗ 2개',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  225: ['2022. 04. 11. (월)\n오후 10:14:00',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  226: ['2022. 04. 11. (월)\n오후 08:52:49',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  227: ['2022. 04. 11. (월)\n오후 07:47:33',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  228: ['2022. 04. 11. (월)\n오후 06:09:52',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  229: ['2022. 04. 11. (월)\n오후 03:16:21',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 1.25L',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  230: ['2022. 04. 11. (월)\n오후 02:25:48',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  231: ['2022. 04. 11. (월)\n오후 12:53:58',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 가쓰오부시 추가',
#   '┗ 사이다 500ml',
#   '┗ 강한맛',
#   '┗ 매콤양념 (맛선택)'],
#  232: ['2022. 04. 11. (월)\n오후 12:50:37',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 마늘간장',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  233: ['2022. 04. 11. (월)\n오전 11:45:08',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 해쉬브라운 2개',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  234: ['2022. 04. 11. (월)\n오전 11:40:09',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  235: ['2022. 04. 10. (일)\n오후 10:26:39',
#   '배달',
#   '사이다\n1개',
#   '┗ 1.25L',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  236: ['2022. 04. 10. (일)\n오후 09:46:54',
#   '배달',
#   '한입핫도그 5개\n1개',
#   '┗ 기본',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오란씨(파인맛) 500ml',
#   '┗ 대파+청양마요 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 중간맛'],
#  237: ['2022. 04. 10. (일)\n오후 09:39:50',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  238: ['2022. 04. 10. (일)\n오후 09:06:05',
#   '배달',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 모듬튀김 8개',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  239: ['2022. 04. 10. (일)\n오후 08:27:03',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)'],
#  240: ['2022. 04. 10. (일)\n오후 08:15:51',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 김말이 4개',
#   '┗ 사이다 500ml',
#   '┗ 약한맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  241: ['2022. 04. 10. (일)\n오후 07:46:21',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 15cm왕새우튀김 3개'],
#  242: ['2022. 04. 10. (일)\n오후 07:11:56',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  243: ['2022. 04. 10. (일)\n오후 06:51:51',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  244: ['2022. 04. 10. (일)\n오후 06:31:19',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 계란찜',
#   '┗ 소떡소떡 1개',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 비엔나 소세지 5개 추가',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 안매운양념 (맛선택)'],
#  245: ['2022. 04. 10. (일)\n오후 06:14:13',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 오리지널 (맛선택)',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본'],
#  246: ['2022. 04. 10. (일)\n오후 06:09:04',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 왕오징어튀김 3개',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  247: ['2022. 04. 10. (일)\n오후 05:15:58',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  248: ['2022. 04. 10. (일)\n오후 03:10:04',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  249: ['2022. 04. 10. (일)\n오후 12:04:08',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  250: ['2022. 04. 10. (일)\n오전 10:40:45',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화 바베큐',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  251: ['2022. 04. 09. (토)\n오후 09:45:32',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n2개',
#   '┗ 1개',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '쿨피스 캔\n2개',
#   '┗ 350ml'],
#  252: ['2022. 04. 09. (토)\n오후 09:01:55',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)'],
#  253: ['2022. 04. 09. (토)\n오후 08:41:19',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)'],
#  254: ['2022. 04. 09. (토)\n오후 08:01:44',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)',
#   '날치알마요 셀프주먹밥\n1개',
#   '┗ 기본'],
#  255: ['2022. 04. 09. (토)\n오후 05:55:55',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  256: ['2022. 04. 09. (토)\n오후 05:19:33',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 게맛살 튀김3개',
#   '┗ 쿨피스 350ml'],
#  257: ['2022. 04. 09. (토)\n오후 12:16:24',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  258: ['2022. 04. 09. (토)\n오전 10:36:00',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  259: ['2022. 04. 08. (금)\n오후 10:19:37',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 계란찜',
#   '┗ 콜라 1.25L 추가',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 펩시콜라 1.25L',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 매콤양념 (맛선택)'],
#  260: ['2022. 04. 08. (금)\n오후 06:28:05',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n3개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  261: ['2022. 04. 08. (금)\n오후 05:22:28',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  262: ['2022. 04. 08. (금)\n오후 01:15:13',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 가쓰오부시 추가',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛'],
#  263: ['2022. 04. 08. (금)\n오후 12:42:19',
#   '배달',
#   '소떡소떡\n1개',
#   '┗ 1개',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  264: ['2022. 04. 08. (금)\n오후 12:35:22',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 갈비천왕',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  265: ['2022. 04. 08. (금)\n오전 11:57:53',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 콜라 500ml 추가',
#   '┗ 매콤양념 (맛선택)'],
#  266: ['2022. 04. 07. (목)\n오후 09:32:37',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
# ...
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  490: ['2022. 03. 01. (화)\n오후 10:04:59',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛'],
#  491: ['2022. 03. 01. (화)\n오후 08:45:39',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  492: ['2022. 03. 01. (화)\n오후 08:17:58',
#   '배달',
#   '수제 등심돈까스\n1개',
#   '┗ 기본',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  493: ['2022. 03. 01. (화)\n오후 07:01:59',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  494: ['2022. 03. 01. (화)\n오후 03:22:36',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  495: ['2022. 03. 01. (화)\n오후 03:21:14',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  496: ['2022. 03. 01. (화)\n오후 03:18:22',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 펩시콜라 355ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  497: ['2022. 03. 01. (화)\n오후 02:39:35',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 직화 바베큐',
#   '┗ 쿨피스 350ml',
#   '해쉬브라운\n1개',
#   '┗ 4개'],
#  498: ['2022. 03. 01. (화)\n오후 02:35:48',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 소떡소떡 1개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양고추+오리지널 (맛선택)'],
#  499: ['2022. 03. 01. (화)\n오후 01:11:49',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)'],
#  500: ['2022. 02. 28. (월)\n오후 10:22:27',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 야끼만두4한입핫도그3'],
#  501: ['2022. 02. 28. (월)\n오후 09:14:40',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 모듬튀김7개 (김말이1,오뎅튀김2,오징어1,야끼2,고구마1)',
#   '┗ 펩시콜라 355ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  502: ['2022. 02. 28. (월)\n오후 05:53:59',
#   '배달',
#   '펩시콜라\n1개',
#   '┗ 1.25L',
#   '수제 등심돈까스\n1개',
#   '┗ 기본',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)'],
#  503: ['2022. 02. 28. (월)\n오후 03:06:19',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '쿨피스 캔\n2개',
#   '┗ 350ml'],
#  504: ['2022. 02. 28. (월)\n오후 02:00:15',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  505: ['2022. 02. 28. (월)\n오후 01:16:44',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 한입핫도그 6개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 355ml'],
#  506: ['2022. 02. 28. (월)\n오전 11:06:49',
#   '배달',
#   '우유튀김 6개\n1개',
#   '┗ 기본',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 펩시콜라 500ml',
#   '┗ 갈비천왕'],
#  507: ['2022. 02. 28. (월)\n오전 11:04:01',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  508: ['2022. 02. 27. (일)\n오후 10:28:32',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛'],
#  509: ['2022. 02. 27. (일)\n오후 09:25:08',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양마요 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 마늘간장',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  510: ['2022. 02. 27. (일)\n오후 05:28:51',
#   '배달',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  511: ['2022. 02. 27. (일)\n오후 02:28:06',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  512: ['2022. 02. 27. (일)\n오후 12:30:29',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  513: ['2022. 02. 27. (일)\n오후 12:12:23',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  514: ['2022. 02. 27. (일)\n오전 11:20:31',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  515: ['2022. 02. 27. (일)\n오전 10:53:22',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  516: ['2022. 02. 27. (일)\n오전 10:41:49',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  517: ['2022. 02. 26. (토)\n오후 09:58:56',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '해쉬브라운\n1개',
#   '┗ 4개',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개'],
#  518: ['2022. 02. 26. (토)\n오후 09:51:29',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 사이다 1.25L 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  519: ['2022. 02. 26. (토)\n오후 07:52:23',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '야끼만두 5개\n1개',
#   '┗ 기본',
#   '왕오징어튀김\n2개',
#   '┗ 2개'],
#  520: ['2022. 02. 26. (토)\n오후 06:28:04',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  521: ['2022. 02. 26. (토)\n오후 02:14:13',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  522: ['2022. 02. 26. (토)\n오후 12:00:13',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  523: ['2022. 02. 24. (목)\n오후 06:16:03',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  524: ['2022. 02. 24. (목)\n오후 06:05:02',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  525: ['2022. 02. 24. (목)\n오후 05:12:11',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 스노윙 치즈볼 4개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  526: ['2022. 02. 24. (목)\n오후 03:27:10',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '사이다\n1개',
#   '┗ 1.25L'],
#  527: ['2022. 02. 24. (목)\n오후 02:27:34',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 펩시콜라 500ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  528: ['2022. 02. 24. (목)\n오전 11:33:35',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 355ml'],
#  529: ['2022. 02. 22. (화)\n오후 10:17:10',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  530: ['2022. 02. 22. (화)\n오후 09:45:24',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '한입핫도그 6개\n1개',
#   '┗ 기본',
#   '우유튀김 6개\n1개',
#   '┗ 기본'],
#  531: ['2022. 02. 22. (화)\n오후 09:36:57',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  532: ['2022. 02. 22. (화)\n오후 09:33:29',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  533: ['2022. 02. 22. (화)\n오후 09:33:29',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 콜라 500ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  534: ['2022. 02. 22. (화)\n오후 09:25:23',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 한입핫도그 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  535: ['2022. 02. 22. (화)\n오후 09:20:00',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  536: ['2022. 02. 22. (화)\n오후 07:44:03',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)'],
#  537: ['2022. 02. 22. (화)\n오후 07:39:38',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파 (토핑추가)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  538: ['2022. 02. 22. (화)\n오후 07:25:20',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 콜라 1.25L 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  539: ['2022. 02. 22. (화)\n오후 03:24:44',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 해쉬브라운 2개',
#   '┗ 가쓰오부시 추가',
#   '┗ 대파+청양고추 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  540: ['2022. 02. 22. (화)\n오후 02:54:04',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  541: ['2022. 02. 22. (화)\n오전 11:27:24',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)'],
#  542: ['2022. 02. 22. (화)\n오전 11:16:16',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  543: ['2022. 02. 21. (월)\n오후 10:16:57',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '사이다\n1개',
#   '┗ 500ml'],
#  544: ['2022. 02. 21. (월)\n오후 09:42:21',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  545: ['2022. 02. 21. (월)\n오후 07:22:18',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  546: ['2022. 02. 21. (월)\n오후 07:11:56',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  547: ['2022. 02. 21. (월)\n오후 06:03:54',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '한입핫도그 6개\n1개',
#   '┗ 기본',
#   '우유튀김 6개\n1개',
#   '┗ 기본'],
#  548: ['2022. 02. 21. (월)\n오후 05:40:18',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '해쉬브라운\n1개',
#   '┗ 2개',
#   '한입핫도그 6개\n1개',
#   '┗ 기본'],
#  549: ['2022. 02. 21. (월)\n오후 01:22:39',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 오징어튀김 2개',
#   '┗ 청양마요소스 (토핑추가)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 왕오징어튀김 3개',
#   '┗ 쿨피스 350ml'],
#  550: ['2022. 02. 21. (월)\n오전 10:47:54',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  551: ['2022. 02. 20. (일)\n오후 10:26:59',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 콜라 1.25L 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '왕오징어튀김\n2개',
#   '┗ 2개',
#   '미니 떡볶이\n2개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '오뎅튀김 6개\n1개',
#   '┗ 기본',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  552: ['2022. 02. 20. (일)\n오후 09:47:35',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  553: ['2022. 02. 20. (일)\n오후 08:51:35',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 사이다 500ml 추가',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)'],
#  554: ['2022. 02. 20. (일)\n오후 02:05:12',
#   '배달',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  555: ['2022. 02. 20. (일)\n오후 01:08:27',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 1.25L',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛'],
#  556: ['2022. 02. 20. (일)\n오전 11:52:22',
#   '배달',
#   '한입핫도그 6개\n1개',
#   '┗ 기본',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  557: ['2022. 02. 20. (일)\n오전 11:37:16',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  558: ['2022. 02. 20. (일)\n오전 11:23:41',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)'],
#  559: ['2022. 02. 20. (일)\n오전 10:57:38',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '쿨피스 캔\n4개',
#   '┗ 350ml'],
#  560: ['2022. 02. 20. (일)\n오전 10:53:47',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '스노윙 치즈볼 4개\n1개',
#   '┗ 기본'],
#  561: ['2022. 02. 20. (일)\n오전 10:48:32',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  562: ['2022. 02. 19. (토)\n오후 08:48:55',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  563: ['2022. 02. 19. (토)\n오후 08:10:00',
#   '배달',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  564: ['2022. 02. 19. (토)\n오후 06:43:07',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  565: ['2022. 02. 19. (토)\n오후 06:13:30',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 1.25L 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)'],
#  566: ['2022. 02. 19. (토)\n오후 05:35:27',
#   '배달',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쫄깃 밀떡10개 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화 바베큐',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  567: ['2022. 02. 19. (토)\n오후 03:22:01',
#   '배달',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 야끼만두4한입핫도그3',
#   '┗ 오리지널 (맛선택)'],
#  568: ['2022. 02. 19. (토)\n오후 03:16:03',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  569: ['2022. 02. 19. (토)\n오후 01:01:14',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  570: ['2022. 02. 18. (금)\n오후 07:53:30',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  571: ['2022. 02. 18. (금)\n오후 06:16:06',
#   '배달',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  572: ['2022. 02. 18. (금)\n오후 01:26:26',
#   '배달',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 대파 (토핑추가)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 콜라 355ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  573: ['2022. 02. 18. (금)\n오전 10:52:38',
#   '배달',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 가쓰오부시 추가',
#   '┗ 청양고추+청양마요 (토핑추가)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)']}

# %% [markdown]
# 주문 메뉴만 추출

# %%
menus = {}
for i in data:
    if data[i][1] == '배달':
        menus[i] = data[i][2:]
    else:
        menus[i] = data[i][1:]

menus
# Out:
# {1: ['이연X의멘보샤(특제소스제공)\n2개',
#   '┗ 4개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  2: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  3: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  4: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 매콤양념치킨',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  5: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  6: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  7: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  8: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 모듬튀김 8개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  9: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  10: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 우유튀김 5개',
#   '┗ 오징어튀김 2개',
#   '┗ 매콤양념 (맛선택)'],
#  11: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 고구마튀김 4개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  12: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본'],
#  13: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  14: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  15: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 매콤양념 (맛선택)'],
#  16: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  17: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 약한맛',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)'],
#  18: ['해쉬브라운\n1개',
#   '┗ 2개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  19: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  20: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '게맛살튀김\n1개',
#   '┗ 3개',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  21: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양고추 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  22: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 왕오징어튀김 3개',
#   '┗ 오리지널 (맛선택)'],
#  23: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  24: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '볶음김치마요 셀프주먹밥\n1개',
#   '┗ 기본',
#   '계란찜\n1개',
#   '┗ 기본'],
#  25: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  26: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  27: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  28: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 청양마요 (맛선택)'],
#  29: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 소떡소떡 1개',
#   '┗ 오징어튀김 2개',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  30: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 오리지널 (맛선택)'],
#  31: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  32: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개'],
#  33: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '날치알마요 셀프주먹밥\n1개',
#   '┗ 기본'],
#  34: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '쿨피스 캔\n2개',
#   '┗ 350ml'],
#  35: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 소떡소떡 1개',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  36: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  37: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  38: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  39: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 안매운양념 (맛선택)'],
#  40: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 치즈스틱 5개',
#   '┗ 쿨피스 350ml'],
#  41: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈스틱 5개',
#   '┗ 파마산치즈+청양마요 (토핑추가)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  42: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 매콤 마늘간장',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  43: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 펩시콜라 355ml',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)'],
#  44: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  45: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  46: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 펩시콜라 1.25L',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  47: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  48: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  49: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 콜라 355ml 추가',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  50: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 청양고추+오리지널 (맛선택)'],
#  51: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  52: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml',
#   '┗ 안매운양념 (맛선택)'],
#  53: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 펩시콜라 1.25L',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  54: ['미니 떡볶이\n1개', '┗ 기본', '┗ 약한맛', '소떡소떡\n2개', '┗ 1개', '치즈볼 4개\n1개', '┗ 기본'],
#  55: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml'],
#  56: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화 바베큐'],
#  57: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  58: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '오란씨(파인맛)\n1개',
#   '┗ 1.5L'],
#  59: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  60: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  61: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  62: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 모듬튀김 8개',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  63: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개',
#   '소떡소떡\n1개',
#   '┗ 1개',
#   '사이다\n1개',
#   '┗ 355ml',
#   '치즈스틱 5개\n1개',
#   '┗ 기본'],
#  64: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 해쉬브라운 2개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 양념치킨'],
#  65: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  66: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  67: ['진로 이즈벡\n2개',
#   '┗ 기본',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 약한맛',
#   '미니오뎅탕\n1개',
#   '┗ 기본',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  68: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  69: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 매콤양념 (맛선택)'],
#  70: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  71: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  72: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 갈비천왕',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml'],
#  73: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  74: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛'],
#  75: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 콜라 355ml 추가',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  76: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  77: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  78: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 이연x멘보샤 3개(특제소스 제공)'],
#  79: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  80: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '치즈볼 4개\n1개',
#   '┗ 기본'],
#  81: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 소떡소떡 1개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  82: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛'],
#  83: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '테라\n1개',
#   '┗ 병'],
#  84: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  85: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  86: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오뎅튀김 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  87: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 양념치킨',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  88: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  89: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛'],
#  90: ['미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)'],
#  91: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  92: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 안매운양념 (맛선택)'],
#  93: ['타코야끼12알 + 치밥 도시락 + 음료1\n2개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  94: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  95: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  96: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  97: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  98: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  99: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  100: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '미니오뎅탕\n1개',
#   '┗ 기본',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본',
#   '카스\n1개',
#   '┗ 병'],
#  101: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오뎅튀김 6개',
#   '┗ 가쓰오부시 추가',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  102: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  103: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 치즈스틱 5개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  104: ['치밥 도시락\n4개', '┗ 기본', '┗ 계란찜', '┗ 갈비천왕'],
#  105: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '쿨피스 캔\n1개',
#   '┗ 350ml'],
#  106: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)'],
#  107: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  108: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  109: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '우유튀김 6개\n1개',
#   '┗ 기본',
#   '사이다\n1개',
#   '┗ 355ml'],
#  110: ['우유튀김 6개\n1개',
#   '┗ 기본',
#   '해쉬브라운\n1개',
#   '┗ 2개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 500ml'],
#  111: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 모듬튀김 8개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  112: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '해쉬브라운\n1개',
#   '┗ 2개'],
#  113: ['치밥 도시락\n4개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '계란찜\n1개',
#   '┗ 기본',
#   '펩시콜라\n4개',
#   '┗ 355ml'],
#  114: ['15cm왕새우튀김\n1개',
#   '┗ 2개',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 중간맛',
#   '┗ 쿨피스 350ml'],
#  115: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '계란찜\n4개',
#   '┗ 기본',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 가쓰오부시 추가',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  116: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 가쓰오부시 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  117: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 500ml'],
#  118: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 마늘간장'],
#  119: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 청양고추 (토핑추가)',
#   '┗ 오리지널 (맛선택)'],
#  120: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 1.25L 추가',
#   '┗ 소떡소떡 1개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  121: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)'],
#  122: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양고추+오리지널 (맛선택)'],
#  123: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  124: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 고구마튀김 4개',
#   '┗ 치즈볼 4개',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)'],
#  125: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 15cm왕새우튀김 3개'],
#  126: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 콜라 500ml 추가',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  127: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 우유튀김 5개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)'],
#  128: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 15cm새우튀김 2개',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)'],
#  129: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 소떡소떡 1개',
#   '┗ 펩시콜라 500ml',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  130: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 고구마튀김 4개',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  131: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  132: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 치즈볼 4개'],
#  133: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  134: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)'],
#  135: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양마요 (맛선택)',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml'],
#  136: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  137: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '허니버터 치즈볼 4개\n1개',
#   '┗ 기본',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  138: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  139: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 스노윙 치즈볼 4개',
#   '┗ 콜라 1.25L 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  140: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  141: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 콜라 355ml 추가',
#   '┗ 오리지널 (맛선택)'],
#  142: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  143: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  144: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 스노윙 치즈볼 4개',
#   '┗ 오징어튀김 2개',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  145: ['우유튀김 6개\n1개',
#   '┗ 기본',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+청양마요 (토핑추가)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  146: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양마요 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 게맛살 튀김3개',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  147: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 우유튀김 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  148: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  149: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  150: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 한입핫도그 6개',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  151: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  152: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  153: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '┗ 갈비천왕'],
#  154: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  155: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)'],
#  156: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  157: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '고구마튀김 4개\n1개',
#   '┗ 기본',
#   '한입핫도그 5개\n1개',
#   '┗ 기본'],
#  158: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추 (토핑추가)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  159: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  160: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 중간맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 펩시콜라 355ml',
#   '날치알마요 셀프주먹밥\n1개',
#   '┗ 기본',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  161: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오란씨(파인맛) 500ml',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  162: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  163: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '게맛살튀김\n1개',
#   '┗ 3개',
#   '펩시콜라\n1개',
#   '┗ 1.25L'],
#  164: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  165: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)'],
#  166: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  167: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  168: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛'],
#  169: ['카스\n1개',
#   '┗ 병',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오뎅튀김 6개',
#   '┗ 펩시콜라 355ml',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)'],
#  170: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 치즈볼 4개'],
#  171: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 24알 추가 (총 36알)',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  172: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n2개',
#   '┗ 1개'],
#  173: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  174: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '미니오뎅탕\n1개',
#   '┗ 기본',
#   '야끼만두 5개\n1개',
#   '┗ 기본'],
#  175: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 15cm왕새우튀김 3개',
#   '┗ 펩시콜라 355ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  176: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 사이다 500ml',
#   '┗ 대파+파마산치즈 (토핑추가)',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화 바베큐'],
#  177: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  178: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 김말이 4개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 약한맛'],
#  179: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 소떡소떡 1개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  180: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  181: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  182: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '해쉬브라운\n1개',
#   '┗ 4개',
#   '펩시콜라\n1개',
#   '┗ 1.25L',
#   '사이다\n1개',
#   '┗ 1.25L'],
#  183: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n1개',
#   '┗ 1개',
#   '펩시콜라\n1개',
#   '┗ 355ml'],
#  184: ['[][]반반 타코야끼12알[][] [두가지맛]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  185: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 야끼만두 5개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 쿨피스 350ml'],
#  186: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 24알 추가 (총 36알)',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 가쓰오부시 추가',
#   '┗ 갈비천왕',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  187: ['게맛살튀김\n1개',
#   '┗ 3개',
#   '쿨피스 캔\n1개',
#   '┗ 350ml',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  188: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 가쓰오부시 추가',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 가쓰오부시 추가',
#   '┗ 대파 (토핑추가)',
#   '┗ 안매운양념 (맛선택)'],
#  189: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  190: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  191: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 소떡소떡 1개',
#   '┗ 해쉬브라운 2개',
#   '┗ 오리지널 (맛선택)'],
#  192: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  193: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 대파 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  194: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본'],
#  195: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛'],
#  196: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)'],
#  197: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 우유튀김 6개',
#   '┗ 펩시콜라 355ml'],
#  198: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 고구마튀김 4개',
#   '┗ 콜라 1.25L 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  199: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 오란씨(파인맛) 1.5L',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  200: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '수제 등심돈까스\n1개',
#   '┗ 기본'],
#  201: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 양념치킨',
#   '┗ 쿨피스 350ml'],
#  202: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  203: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  204: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  205: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 15cm새우튀김 2개',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  206: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  207: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 1.25L',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)'],
#  208: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)'],
#  209: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 가쓰오부시 추가',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  210: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 매콤양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  211: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '카스\n1개',
#   '┗ 병'],
#  212: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 매콤양념 (맛선택)'],
#  213: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 오징어튀김 2개',
#   '┗ 매콤양념 (맛선택)'],
#  214: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 500ml 추가',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 매콤양념 (맛선택)'],
#  215: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 찰김말이 6개',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 쿨피스 350ml'],
#  216: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 가쓰오부시 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  217: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 약한맛'],
#  218: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  219: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '┗ 펩시콜라 355ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  220: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파 (토핑추가)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  221: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)'],
#  222: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 한입핫도그 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 쿨피스 350ml',
#   '┗ 강한맛',
#   '┗ 오리지널 (맛선택)'],
#  223: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml'],
#  224: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '오란씨(파인맛)\n1개',
#   '┗ 1.5L',
#   '해쉬브라운\n1개',
#   '┗ 2개',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  225: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  226: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  227: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  228: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개'],
#  229: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 1.25L',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  230: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  231: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 가쓰오부시 추가',
#   '┗ 사이다 500ml',
#   '┗ 강한맛',
#   '┗ 매콤양념 (맛선택)'],
#  232: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 마늘간장',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  233: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 해쉬브라운 2개',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  234: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  235: ['사이다\n1개',
#   '┗ 1.25L',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  236: ['한입핫도그 5개\n1개',
#   '┗ 기본',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오란씨(파인맛) 500ml',
#   '┗ 대파+청양마요 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 중간맛'],
#  237: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  238: ['미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 모듬튀김 8개',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  239: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)'],
#  240: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 김말이 4개',
#   '┗ 사이다 500ml',
#   '┗ 약한맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  241: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 15cm왕새우튀김 3개'],
#  242: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  243: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  244: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 계란찜',
#   '┗ 소떡소떡 1개',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 비엔나 소세지 5개 추가',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 안매운양념 (맛선택)'],
#  245: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 오리지널 (맛선택)',
#   '참이슬 후레쉬\n1개',
#   '┗ 기본'],
#  246: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 왕오징어튀김 3개',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  247: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  248: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  249: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  250: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화 바베큐',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  251: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n2개',
#   '┗ 1개',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '쿨피스 캔\n2개',
#   '┗ 350ml'],
#  252: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)'],
#  253: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)'],
#  254: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)',
#   '날치알마요 셀프주먹밥\n1개',
#   '┗ 기본'],
#  255: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  256: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 게맛살 튀김3개',
#   '┗ 쿨피스 350ml'],
#  257: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  258: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  259: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 계란찜',
#   '┗ 콜라 1.25L 추가',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 펩시콜라 1.25L',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 매콤양념 (맛선택)'],
#  260: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n3개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  261: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  262: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 소떡소떡 1개',
#   '┗ 가쓰오부시 추가',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛'],
#  263: ['소떡소떡\n1개',
#   '┗ 1개',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  264: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 갈비천왕',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  265: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 콜라 500ml 추가',
#   '┗ 매콤양념 (맛선택)'],
#  266: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  267: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 치즈스틱 6개',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)'],
#  268: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  269: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 해쉬브라운 3개',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml'],
#  270: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 콜라 355ml 추가',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  271: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)'],
#  272: ['진로 이즈벡\n1개',
#   '┗ 기본',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  273: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛'],
#  274: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 콜라 1.25L 추가',
#   '┗ 바베큐 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  275: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '치즈볼 4개\n1개',
#   '┗ 기본',
#   '오란씨(파인맛)\n1개',
#   '┗ 500ml'],
#  276: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오란씨(파인맛) 1.5L',
#   '┗ 바베큐 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  277: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  278: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  279: ['[][]반반 타코야끼12알[][] [두가지맛]\n2개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '야끼만두 5개\n1개',
#   '┗ 기본'],
#  280: ['15cm왕새우튀김\n1개',
#   '┗ 2개',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  281: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 1.25L',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '볶음김치마요 셀프주먹밥\n1개',
#   '┗ 기본'],
#  282: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 가쓰오부시 추가',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '생수 (몽베스트)\n1개',
#   '┗ 500ml'],
#  283: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  284: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  285: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  286: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  287: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  288: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛'],
#  289: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  290: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  291: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  292: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 안매운양념 (맛선택)'],
#  293: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)'],
#  294: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 모듬튀김 8개',
#   '┗ 계란찜',
#   '┗ 우유튀김 6개',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  295: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  296: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 500ml',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 중간맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  297: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 김말이 4개',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 약한맛'],
#  298: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 안매운양념 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)'],
#  299: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개'],
#  300: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 갈비천왕',
#   '┗ 매콤양념 (맛선택)'],
#  301: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  302: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)',
#   '수제 등심돈까스\n1개',
#   '┗ 기본'],
#  303: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '수제 등심돈까스\n1개',
#   '┗ 기본'],
#  304: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  305: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 콜라 1.25L 추가',
#   '┗ 가쓰오부시 추가',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  306: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 양념치킨',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  307: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '소떡소떡\n1개',
#   '┗ 1개',
#   '사이다\n1개',
#   '┗ 355ml'],
#  308: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 안매운양념 (맛선택)'],
#  309: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  310: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  311: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화 바베큐'],
#  312: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  313: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 김말이 4개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 중간맛',
#   '┗ 쿨피스 350ml'],
#  314: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 스노윙 치즈볼 4개',
#   '┗ 바베큐 (맛선택)',
#   '타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 약한맛',
#   '게맛살튀김\n1개',
#   '┗ 3개',
#   '오뎅튀김 6개\n1개',
#   '┗ 기본',
#   '치즈스틱 5개\n1개',
#   '┗ 기본',
#   '펩시콜라\n1개',
#   '┗ 1.25L'],
#  315: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 24알 추가 (총 36알)',
#   '┗ 12알',
#   '┗ 치즈볼 4개',
#   '┗ 15cm새우튀김 2개',
#   '┗ 김말이 4개',
#   '┗ 콜라 500ml 추가',
#   '┗ 안매운양념 (맛선택)'],
#  316: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)'],
#  317: ['김말이 4개\n1개',
#   '┗ 기본',
#   '이연X의멘보샤(특제소스제공)\n2개',
#   '┗ 4개',
#   '우유튀김 6개\n1개',
#   '┗ 기본'],
#  318: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  319: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 오리지널 (맛선택)'],
#  320: ['미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '볶음김치마요 셀프주먹밥\n1개',
#   '┗ 기본',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  321: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 찰김말이 6개'],
#  322: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  323: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  324: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 중간맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  325: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 모듬튀김7개 (김말이1,오뎅튀김2,오징어1,야끼2,고구마1)'],
#  326: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 해쉬브라운 2개',
#   '┗ 펩시콜라 1.25L',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  327: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 해쉬브라운 2개',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  328: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛',
#   '┗ 펩시콜라 355ml',
#   '┗ 매콤양념 (맛선택)'],
#  329: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '쿨피스 캔\n1개',
#   '┗ 350ml'],
#  330: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 15cm왕새우튀김 3개',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)'],
#  331: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오징어튀김 2개',
#   '┗ 메추리알 5개 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  332: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 약한맛',
#   '┗ 매콤양념 (맛선택)'],
#  333: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 콜라 500ml 추가',
#   '┗ 안매운양념 (맛선택)'],
#  334: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오징어튀김 2개',
#   '┗ 콜라 355ml 추가',
#   '┗ 오리지널 (맛선택)'],
#  335: ['미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  336: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  337: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  338: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  339: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛'],
#  340: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  341: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  342: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  343: ['해쉬브라운\n1개',
#   '┗ 2개',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)'],
#  344: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  345: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  346: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)'],
#  347: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  348: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)'],
#  349: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 가쓰오부시 추가',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  350: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 오란씨(파인맛) 1.5L',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  351: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
# ...
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '왕오징어튀김\n1개',
#   '┗ 2개',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  465: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml'],
#  466: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  467: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 쫄깃 밀떡10개 추가',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 갈비천왕'],
#  468: ['치밥 도시락\n1개', '┗ 기본', '┗ 콜라 1.25L 추가', '┗ 오징어튀김 2개', '┗ 갈비천왕'],
#  469: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 야끼만두4한입핫도그3',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml'],
#  470: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 한입핫도그 6개',
#   '┗ 오뎅튀김 6개',
#   '┗ 해쉬브라운 2개',
#   '┗ 오리지널 (맛선택)'],
#  471: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 15cm새우튀김 2개',
#   '┗ 오징어튀김 2개',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  472: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 24알 추가 (총 36알)',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '한입핫도그 5개\n1개',
#   '┗ 기본',
#   '펩시콜라\n1개',
#   '┗ 1.25L'],
#  473: ['미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '수제 등심돈까스\n1개',
#   '┗ 기본',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '우유튀김 6개\n1개',
#   '┗ 기본'],
#  474: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  475: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '우유튀김 6개\n1개',
#   '┗ 기본'],
#  476: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 우유튀김 6개',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  477: ['미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 소떡소떡 1개',
#   '┗ 오란씨(파인맛) 1.5L',
#   '┗ 등심돈까스 1장',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  478: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  479: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '소떡소떡\n1개',
#   '┗ 1개',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개'],
#  480: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 한입핫도그 6개',
#   '┗ 콜라 500ml 추가',
#   '┗ 쿨피스 350ml 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛'],
#  481: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 양념치킨',
#   '┗ 오리지널 (맛선택)'],
#  482: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)'],
#  483: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요소스 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '스노윙 치즈볼 4개\n1개',
#   '┗ 기본'],
#  484: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈+청양마요 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 15cm왕새우튀김 3개'],
#  485: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추 (토핑추가)',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념치킨'],
#  486: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 갈비천왕'],
#  487: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)'],
#  488: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  489: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  490: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛'],
#  491: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  492: ['수제 등심돈까스\n1개',
#   '┗ 기본',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  493: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  494: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  495: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  496: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 펩시콜라 355ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  497: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 직화 바베큐',
#   '┗ 쿨피스 350ml',
#   '해쉬브라운\n1개',
#   '┗ 4개'],
#  498: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 볶음김치마요 셀프주먹밥',
#   '┗ 소떡소떡 1개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 청양고추+오리지널 (맛선택)'],
#  499: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 소떡소떡 1개',
#   '┗ 오리지널 (맛선택)'],
#  500: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 야끼만두4한입핫도그3'],
#  501: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 모듬튀김7개 (김말이1,오뎅튀김2,오징어1,야끼2,고구마1)',
#   '┗ 펩시콜라 355ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  502: ['펩시콜라\n1개',
#   '┗ 1.25L',
#   '수제 등심돈까스\n1개',
#   '┗ 기본',
#   '[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)'],
#  503: ['치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '쿨피스 캔\n2개',
#   '┗ 350ml'],
#  504: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  505: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 한입핫도그 6개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 355ml'],
#  506: ['우유튀김 6개\n1개',
#   '┗ 기본',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 펩시콜라 500ml',
#   '┗ 갈비천왕'],
#  507: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  508: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛'],
#  509: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 청양마요 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 마늘간장',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  510: ['치밥 도시락\n1개', '┗ 기본', '┗ 소떡소떡 1개', '┗ 직화양념(매콤) 지코X스타일'],
#  511: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 15cm새우튀김 2개',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  512: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)'],
#  513: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 펩시콜라 355ml'],
#  514: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 이연x멘보샤 3개(특제소스 제공)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  515: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  516: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)'],
#  517: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '해쉬브라운\n1개',
#   '┗ 4개',
#   '이연X의멘보샤(특제소스제공)\n1개',
#   '┗ 4개'],
#  518: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 사이다 1.25L 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  519: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '야끼만두 5개\n1개',
#   '┗ 기본',
#   '왕오징어튀김\n2개',
#   '┗ 2개'],
#  520: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  521: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  522: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  523: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛',
#   '김말이 4개\n1개',
#   '┗ 기본'],
#  524: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 48알 (12알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  525: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 스노윙 치즈볼 4개',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  526: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)',
#   '사이다\n1개',
#   '┗ 1.25L'],
#  527: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 바베큐 (맛선택)',
#   '┗ 펩시콜라 500ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  528: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '펩시콜라\n1개',
#   '┗ 355ml'],
#  529: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트(펩시콜라355ml)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 안매운양념 (맛선택)'],
#  530: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '한입핫도그 6개\n1개',
#   '┗ 기본',
#   '우유튀김 6개\n1개',
#   '┗ 기본'],
#  531: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  532: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  533: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 콜라 500ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '소떡소떡\n1개',
#   '┗ 1개'],
#  534: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 한입핫도그 6개',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  535: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 매콤양념 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  536: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n2개', '┗ 12알', '┗ 대파+오리지널 (맛선택)'],
#  537: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 대파 (토핑추가)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  538: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 콜라 1.25L 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  539: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 해쉬브라운 2개',
#   '┗ 가쓰오부시 추가',
#   '┗ 대파+청양고추 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  540: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 날치알마요 셀프주먹밥',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트(쿨피스350ml)'],
#  541: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)'],
#  542: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 355ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  543: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 바베큐 (맛선택)',
#   '사이다\n1개',
#   '┗ 500ml'],
#  544: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  545: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  546: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  547: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)',
#   '한입핫도그 6개\n1개',
#   '┗ 기본',
#   '우유튀김 6개\n1개',
#   '┗ 기본'],
#  548: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '해쉬브라운\n1개',
#   '┗ 2개',
#   '한입핫도그 6개\n1개',
#   '┗ 기본'],
#  549: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 왕등심 돈까스(특제소스 제공)',
#   '┗ 오징어튀김 2개',
#   '┗ 청양마요소스 (토핑추가)',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 왕오징어튀김 3개',
#   '┗ 쿨피스 350ml'],
#  550: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml'],
#  551: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 12알',
#   '┗ 콜라 1.25L 추가',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ 청양고추+오리지널 (맛선택)',
#   '왕오징어튀김\n2개',
#   '┗ 2개',
#   '미니 떡볶이\n2개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '오뎅튀김 6개\n1개',
#   '┗ 기본',
#   '미니오뎅탕\n1개',
#   '┗ 기본'],
#  552: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 12알 추가 (총 24알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  553: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 사이다 500ml 추가',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)'],
#  554: ['[ 네가지맛 ] 타코 야끼 24~48알\n1개',
#   '┗ 24알 (6알씩 X 4가지맛)',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  555: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 펩시콜라 1.25L',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 약한맛'],
#  556: ['한입핫도그 6개\n1개',
#   '┗ 기본',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 약한맛',
#   '[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 매콤양념 (맛선택)'],
#  557: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 대파+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '┗ 매콤양념 (맛선택)'],
#  558: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)'],
#  559: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 오리지널 (맛선택)',
#   '┗ 쿨피스 350ml',
#   '┗ 직화양념(매콤) 지코X스타일',
#   '쿨피스 캔\n4개',
#   '┗ 350ml'],
#  560: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 파마산치즈+오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '스노윙 치즈볼 4개\n1개',
#   '┗ 기본'],
#  561: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 오리지널 (맛선택)',
#   '┗ 약한맛',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  562: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 치킨 피카츄 1개(소스 뿌려드려요)',
#   '┗ 매콤양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 안매운양념 (맛선택)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 오리지널 (맛선택)',
#   '15cm왕새우튀김\n1개',
#   '┗ 2개'],
#  563: ['타코야끼12알 + 미니떡볶이 + 음료1\n1개',
#   '┗ 기본',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 쿨피스 350ml',
#   '┗ 중간맛',
#   '┗ 오리지널 (맛선택)'],
#  564: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 허니버터 치즈볼 4개',
#   '┗ 바베큐 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  565: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 콜라 1.25L 추가',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)'],
#  566: ['타코야끼12알 + 치밥 도시락 + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쫄깃 밀떡10개 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ 펩시콜라 355ml',
#   '┗ 직화 바베큐',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  567: ['타코야끼12알 + 튀김(선택) + 음료1\n1개',
#   '┗ 기본',
#   '┗ 쿨피스 350ml',
#   '┗ 야끼만두4한입핫도그3',
#   '┗ 오리지널 (맛선택)'],
#  568: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ 대파 (토핑추가)',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '미니 떡볶이\n1개',
#   '┗ 기본',
#   '┗ 중간맛'],
#  569: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 멘보샤 4개(특제소스 제공)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ 안매운양념 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  570: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 청양마요 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '┗ 오리지널 (맛선택)',
#   '치밥 도시락\n1개',
#   '┗ 기본',
#   '┗ 직화양념(매콤) 지코X스타일'],
#  571: ['[ 세가지맛 ] 타코야끼 36알\n1개',
#   '┗ 36알',
#   '┗ 바베큐 (맛선택)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 오리지널 (맛선택)'],
#  572: ['乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 대파 (토핑추가)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 파마산치즈 (토핑추가)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)',
#   '乃乃타코야끼12알 [배달타코야끼 맛집]\n1개',
#   '┗ 12알',
#   '┗ 콜라 355ml 추가',
#   '┗ 오리지널 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)'],
#  573: ['[][]반반 타코야끼12알[][] [두가지맛]\n1개',
#   '┗ 12알',
#   '┗ 소떡소떡 1개',
#   '┗ 가쓰오부시 추가',
#   '┗ 청양고추+청양마요 (토핑추가)',
#   '┗ 청양마요 (맛선택)',
#   '┗ 바베큐 (맛선택)',
#   '┗ ㄹl뷰 ㅇl벤트 (타코알 4알)']}

# %%
menu_main = ['치밥', '야끼만두', '게맛살', '멘보샤', '해쉬브라운', '우유튀김', '왕오징어튀김',
             '모듬튀김', '치즈스틱', '고구마튀김', '왕새우튀김', '김말이', '수제돈까스', '쿨피스', '펩시콜라', '사이다', '오란씨',
             '토핑추가', '떡볶이', '계란찜', '미니오뎅탕', '소떡소떡', '스노윙 치즈볼', '허니버터 치즈볼', '오뎅튀김',
             '셀프주먹밥', '한입핫도그', '생수', '카스', '테라', '참이슬', '진로', '시원']
menu_eng = ['Chibab', 'Yakimandu', 'Crab', 'Menbo', 'Hashbrown', 'milkfries', 'FriedSquid',
             'FriesSet', 'CheeseStick', 'SPFries', 'FriedShrimp', 'Kimmari', 'Donkats', 'Coolpeace', 'Pepsi', 'Cider', 'OranC',
             'Toppings', 'Teokboki', 'Gyeranzzim', 'Odengtang', 'Sotteock', 'Cheeseball', 'Cheeseball', 'FriedOdeng',
             'Selfjumeokbab', 'miniHotdog', 'Water', 'Cass', 'Tera', 'Chamisl', 'Jinro', 'Siwon']

menu_list = {}

for k, v in menus.items():
    menu_list[k] = []
    for e in v:
        for m, eng in zip(menu_main, menu_eng):
            if m in e:
                if m not in menu_list[k]:
                    menu_list[k].append(eng)
basket = []
for b in menu_list.values():
    if b == []:
        pass
    else:
        basket.append(b)
basket
# Out:
# [['Menbo'],
#  ['Chibab', 'FriedSquid', 'Teokboki', 'Kimmari'],
#  ['Sotteock', 'FriedSquid'],
#  ['Chibab', 'Pepsi'],
#  ['FriesSet'],
#  ['milkfries'],
#  ['SPFries'],
#  ['Chamisl'],
#  ['Chibab'],
#  ['Chibab', 'FriedShrimp'],
#  ['Selfjumeokbab', 'Pepsi'],
#  ['Teokboki', 'FriedSquid'],
#  ['Teokboki', 'Sotteock', 'Pepsi'],
#  ['Hashbrown', 'FriedSquid'],
#  ['FriedShrimp'],
#  ['Crab', 'Odengtang'],
#  ['Sotteock', 'Toppings'],
#  ['Coolpeace', 'FriedSquid'],
#  ['Menbo'],
#  ['Selfjumeokbab', 'Gyeranzzim'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab'],
#  ['Sotteock'],
#  ['Menbo'],
#  ['Coolpeace', 'Selfjumeokbab'],
#  ['Coolpeace', 'Coolpeace'],
#  ['Selfjumeokbab', 'Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Sotteock'],
#  ['Pepsi', 'Sotteock'],
#  ['Chibab', 'Pepsi'],
#  ['CheeseStick', 'Coolpeace'],
#  ['CheeseStick', 'Toppings'],
#  ['Chibab', 'Sotteock'],
#  ['Sotteock', 'Pepsi', 'Menbo'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Pepsi', 'Toppings'],
#  ['Menbo'],
#  ['Chibab', 'Sotteock', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki', 'Sotteock'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Coolpeace', 'Coolpeace'],
#  ['Chibab', 'OranC'],
#  ['Sotteock'],
#  ['Pepsi'],
#  ['FriesSet'],
#  ['Chibab', 'Menbo', 'Sotteock', 'Cider', 'CheeseStick'],
#  ['Hashbrown', 'Chibab'],
#  ['Chibab', 'Coolpeace'],
#  ['Jinro', 'Teokboki', 'Pepsi', 'Coolpeace', 'Odengtang', 'Teokboki'],
#  ['Toppings'],
#  ['Pepsi'],
#  ['Chibab', 'Cheeseball', 'Chibab', 'Coolpeace'],
#  ['Teokboki', 'Toppings', 'Coolpeace'],
#  ['Pepsi', 'Menbo'],
#  ['Chibab', 'Pepsi'],
#  ['Pepsi'],
#  ['Sotteock'],
#  ['Teokboki', 'Pepsi'],
#  ['Tera'],
#  ['FriedOdeng', 'Toppings'],
#  ['Chibab', 'Teokboki', 'FriedSquid', 'Kimmari'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Menbo', 'Pepsi'],
#  ['Pepsi'],
#  ['Odengtang', 'Chamisl', 'Cass'],
#  ['Menbo', 'FriedOdeng'],
#  ['Cheeseball', 'CheeseStick'],
#  ['Chibab', 'Gyeranzzim'],
#  ['Coolpeace', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['milkfries', 'Cider'],
#  ['milkfries', 'Hashbrown', 'Pepsi'],
#  ['FriesSet'],
#  ['FriedShrimp', 'Teokboki', 'Hashbrown'],
#  ['Chibab', 'Gyeranzzim', 'Pepsi'],
#  ['FriedShrimp', 'Teokboki', 'Coolpeace'],
#  ['Gyeranzzim'],
#  ['Coolpeace'],
#  ['Pepsi'],
#  ['Chibab'],
#  ['Selfjumeokbab', 'Toppings'],
#  ['Sotteock'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Pepsi', 'Teokboki'],
#  ['SPFries', 'Sotteock'],
#  ['Coolpeace', 'FriedShrimp'],
#  ['Sotteock'],
#  ['milkfries', 'Pepsi'],
#  ['Toppings'],
#  ['Chibab', 'Selfjumeokbab', 'Sotteock', 'Pepsi'],
#  ['SPFries', 'Coolpeace', 'Pepsi'],
#  ['Menbo'],
#  ['Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Cheeseball', 'FriedSquid'],
#  ['Cheeseball'],
#  ['Teokboki', 'Pepsi'],
#  ['Cheeseball'],
#  ['milkfries', 'Menbo', 'Toppings', 'Toppings'],
#  ['Pepsi', 'Crab', 'FriedShrimp'],
#  ['milkfries'],
#  ['miniHotdog'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Menbo'],
#  ['SPFries', 'miniHotdog'],
#  ['Toppings', 'Menbo', 'Coolpeace'],
#  ['Teokboki'],
#  ['Teokboki', 'Pepsi', 'Selfjumeokbab', 'FriedShrimp'],
#  ['OranC', 'Toppings'],
#  ['Crab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace', 'FriedSquid', 'FriedShrimp'],
#  ['Teokboki', 'Pepsi'],
#  ['Cass', 'Teokboki', 'FriedOdeng', 'Pepsi'],
#  ['Coolpeace'],
#  ['Sotteock'],
#  ['Chibab', 'Chibab', 'Coolpeace'],
#  ['Odengtang', 'Yakimandu'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Sotteock', 'Cider', 'Toppings'],
#  ['Pepsi'],
#  ['Teokboki', 'Kimmari', 'Pepsi'],
#  ['Chibab', 'Sotteock'],
#  ['Hashbrown', 'Pepsi', 'Cider'],
#  ['Sotteock', 'Pepsi'],
#  ['Yakimandu', 'Menbo', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Crab', 'Coolpeace', 'Pepsi'],
#  ['Toppings', 'Toppings'],
#  ['Sotteock', 'Hashbrown'],
#  ['Toppings'],
#  ['Toppings'],
#  ['Teokboki', 'Coolpeace', 'Chamisl'],
#  ['Teokboki', 'Pepsi'],
#  ['Menbo', 'Pepsi'],
#  ['milkfries', 'Pepsi'],
#  ['SPFries'],
#  ['OranC'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Chibab'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi', 'Menbo'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab', 'Selfjumeokbab', 'Pepsi', 'Pepsi', 'Teokboki', 'FriedSquid'],
#  ['Cass'],
#  ['Coolpeace'],
#  ['Pepsi'],
#  ['Kimmari', 'Pepsi', 'Coolpeace'],
#  ['Chibab', 'Menbo', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Sotteock', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['Toppings', 'Odengtang'],
#  ['Teokboki', 'miniHotdog', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['OranC', 'Hashbrown', 'Kimmari'],
#  ['Teokboki'],
#  ['Selfjumeokbab'],
#  ['Chibab', 'Coolpeace', 'Teokboki', 'FriedSquid'],
#  ['Pepsi'],
#  ['Teokboki', 'Cider'],
#  ['Chibab', 'Sotteock'],
#  ['Teokboki', 'Selfjumeokbab', 'Hashbrown', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Cider'],
#  ['miniHotdog', 'Teokboki', 'OranC', 'Toppings'],
#  ['Teokboki', 'FriesSet', 'Selfjumeokbab'],
#  ['Teokboki', 'Kimmari', 'Cider'],
#  ['Coolpeace', 'FriedShrimp'],
#  ['Chibab', 'Gyeranzzim', 'Sotteock', 'Coolpeace', 'Coolpeace'],
#  ['Chamisl'],
#  ['FriedSquid', 'Coolpeace'],
#  ['Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Sotteock', 'Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi', 'Selfjumeokbab'],
#  ['Menbo'],
#  ['Crab', 'Coolpeace'],
#  ['Chibab', 'Chibab', 'Coolpeace'],
#  ['Chibab', 'Gyeranzzim', 'Pepsi'],
#  ['Sotteock'],
#  ['Teokboki', 'Sotteock', 'Coolpeace'],
#  ['Sotteock', 'FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi'],
#  ['CheeseStick', 'Sotteock'],
#  ['Hashbrown', 'Pepsi'],
#  ['Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Jinro', 'Teokboki', 'Coolpeace', 'FriedSquid', 'FriedShrimp'],
#  ['Teokboki'],
#  ['OranC'],
#  ['Chibab', 'OranC'],
#  ['Chibab'],
#  ['Teokboki', 'FriedShrimp'],
#  ['Yakimandu'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Pepsi', 'Selfjumeokbab'],
#  ['Water'],
#  ['Chibab', 'Coolpeace'],
#  ['Cheeseball'],
#  ['Sotteock'],
#  ['Cheeseball'],
#  ['Teokboki', 'Toppings', 'Coolpeace'],
#  ['Chibab', 'Teokboki'],
#  ['Teokboki', 'Coolpeace'],
#  ['Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['FriesSet', 'Gyeranzzim', 'milkfries', 'Toppings'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki', 'Kimmari', 'Coolpeace'],
#  ['Pepsi'],
#  ['Teokboki', 'Coolpeace', 'Menbo'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Sotteock', 'Cider'],
#  ['Pepsi'],
#  ['Pepsi'],
#  ['Chibab', 'Coolpeace', 'Chibab'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Kimmari', 'Coolpeace'],
#  ['Cheeseball',
#   'Cheeseball',
#   'Teokboki',
#   'Coolpeace',
#   'Crab',
#   'FriedOdeng',
#   'CheeseStick',
#   'Pepsi'],
#  ['Kimmari'],
#  ['Chibab', 'Pepsi'],
#  ['Kimmari', 'Menbo', 'milkfries'],
#  ['Teokboki', 'Selfjumeokbab', 'Kimmari'],
#  ['Coolpeace', 'Kimmari'],
#  ['Selfjumeokbab'],
#  ['Teokboki', 'Coolpeace'],
#  ['Coolpeace', 'FriesSet', 'Kimmari', 'FriedOdeng'],
#  ['Chibab', 'Hashbrown', 'Pepsi'],
#  ['Hashbrown'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki'],
#  ['Chibab', 'Coolpeace', 'Teokboki'],
#  ['Teokboki', 'Coolpeace'],
#  ['Hashbrown'],
#  ['Odengtang'],
#  ['Selfjumeokbab', 'Menbo', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock'],
#  ['OranC'],
#  ['Coolpeace', 'FriesSet', 'Kimmari', 'FriedOdeng'],
#  ['Chibab', 'Hashbrown', 'Pepsi', 'Coolpeace'],
#  ['Coolpeace', 'Chibab'],
#  ['Chibab', 'OranC'],
#  ['milkfries'],
#  ['Cheeseball'],
#  ['Pepsi'],
#  ['Menbo'],
#  ['Coolpeace', 'Yakimandu', 'miniHotdog', 'Chibab', 'Coolpeace', 'Cider'],
#  ['Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Pepsi', 'FriedOdeng'],
#  ['Pepsi'],
#  ['Teokboki', 'Pepsi', 'Coolpeace'],
#  ['Coolpeace'],
#  ['Teokboki'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace', 'Pepsi'],
#  ['Sotteock'],
#  ['Chibab', 'OranC'],
#  ['Pepsi', 'Teokboki', 'Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Teokboki', 'Odengtang', 'miniHotdog'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['milkfries', 'Pepsi'],
#  ['Chibab', 'Hashbrown', 'Cider'],
#  ['Toppings'],
#  ['Cider', 'Menbo'],
#  ['FriedShrimp', 'FriedSquid', 'Yakimandu'],
#  ['Coolpeace', 'FriesSet', 'Kimmari', 'FriedOdeng'],
#  ['Chibab'],
#  ['Cheeseball'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi', 'FriedSquid'],
#  ['miniHotdog'],
#  ['Chibab', 'Cider', 'Coolpeace'],
#  ['Hashbrown', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Menbo'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Coolpeace'],
#  ['FriedSquid', 'Coolpeace', 'miniHotdog'],
#  ['Chibab'],
#  ['Pepsi', 'FriedSquid', 'Coolpeace'],
#  ['Crab'],
#  ['Teokboki', 'Coolpeace'],
#  ['milkfries', 'FriedShrimp'],
#  ['Chibab', 'miniHotdog'],
#  ['Sotteock', 'Pepsi', 'Teokboki'],
#  ['Chibab', 'Pepsi'],
#  ['Cider'],
#  ['Chibab'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab'],
#  ['Teokboki', 'Pepsi'],
#  ['Chibab', 'Gyeranzzim', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock', 'Teokboki'],
#  ['FriedShrimp', 'Hashbrown'],
#  ['Teokboki'],
#  ['Teokboki', 'Hashbrown', 'milkfries', 'Coolpeace'],
#  ['Chamisl', 'milkfries'],
#  ['Chibab', 'SPFries', 'Cider'],
#  ['FriedShrimp', 'Pepsi'],
#  ['Selfjumeokbab', 'Coolpeace'],
#  ['Crab', 'Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Toppings', 'Pepsi', 'Jinro'],
#  ['Menbo', 'FriedShrimp'],
#  ['Chibab', 'Pepsi', 'Pepsi'],
#  ['milkfries'],
#  ['Sotteock', 'Coolpeace'],
#  ['Chibab', 'SPFries'],
#  ['Chibab', 'Coolpeace'],
#  ['Chamisl'],
#  ['Chibab', 'Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Toppings', 'Pepsi'],
#  ['Toppings'],
#  ['Chibab', 'Pepsi', 'Chibab'],
#  ['Toppings'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab'],
#  ['Selfjumeokbab', 'SPFries', 'Menbo', 'FriedShrimp'],
#  ['Chibab', 'Coolpeace', 'Chibab', 'FriesSet', 'Teokboki'],
#  ['Cheeseball', 'Pepsi'],
#  ['Chibab',
#   'Kimmari',
#   'SPFries',
#   'Teokboki',
#   'Coolpeace',
#   'Chibab',
#   'Hashbrown'],
#  ['Chibab', 'milkfries', 'Coolpeace', 'Coolpeace'],
#  ['Toppings', 'Coolpeace', 'FriedShrimp'],
#  ['Pepsi'],
#  ['Teokboki', 'milkfries', 'Pepsi'],
#  ['Teokboki', 'Pepsi'],
#  ['Teokboki'],
#  ['Chibab', 'Coolpeace'],
#  ['FriedSquid', 'Teokboki', 'Kimmari'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki'],
#  ['Chibab', 'Selfjumeokbab', 'Coolpeace', 'Teokboki', 'Chibab'],
#  ['Chibab'],
#  ['Yakimandu', 'miniHotdog', 'Pepsi'],
#  ['miniHotdog', 'FriedOdeng', 'Hashbrown'],
#  ['Pepsi'],
#  ['miniHotdog', 'Pepsi'],
#  ['Teokboki', 'milkfries'],
#  ['Coolpeace', 'Menbo', 'milkfries'],
#  ['milkfries'],
#  ['Teokboki', 'Selfjumeokbab', 'Sotteock', 'OranC'],
#  ['Sotteock', 'Menbo'],
#  ['miniHotdog', 'Coolpeace', 'Teokboki'],
#  ['Chibab', 'Coolpeace'],
#  ['Pepsi'],
#  ['Toppings', 'Coolpeace', 'Cheeseball'],
#  ['Toppings', 'Pepsi', 'FriedShrimp'],
#  ['Chibab', 'Toppings', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Menbo'],
#  ['Teokboki', 'Pepsi'],
#  ['Menbo', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Teokboki', 'Pepsi', 'Coolpeace'],
#  ['Chibab', 'Pepsi', 'Coolpeace', 'Hashbrown'],
#  ['Pepsi', 'Selfjumeokbab', 'Sotteock'],
#  ['Menbo', 'Sotteock'],
#  ['Coolpeace', 'Yakimandu', 'miniHotdog'],
#  ['FriesSet', 'Kimmari', 'FriedOdeng', 'Pepsi'],
#  ['Pepsi'],
#  ['Chibab', 'Coolpeace'],
#  ['miniHotdog', 'Pepsi'],
#  ['milkfries', 'Menbo', 'Chibab', 'Pepsi'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Sotteock'],
#  ['Chibab', 'Coolpeace'],
#  ['Chibab', 'Pepsi'],
#  ['Pepsi', 'Menbo'],
#  ['Hashbrown', 'Menbo'],
#  ['Cider', 'Odengtang'],
#  ['Yakimandu', 'FriedSquid'],
#  ['Menbo'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace', 'Coolpeace'],
#  ['Teokboki', 'Kimmari'],
#  ['Cheeseball'],
#  ['Cider'],
#  ['Chibab', 'Pepsi'],
#  ['Pepsi'],
#  ['Pepsi'],
#  ['miniHotdog', 'milkfries'],
#  ['Chibab', 'Coolpeace'],
#  ['Sotteock', 'Sotteock'],
#  ['Cheeseball', 'miniHotdog'],
#  ['Chibab'],
#  ['Toppings', 'Teokboki'],
#  ['Menbo'],
#  ['Chibab', 'Hashbrown', 'Toppings', 'Coolpeace'],
#  ['Chibab', 'Selfjumeokbab', 'Coolpeace', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['Cider'],
#  ['Teokboki', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['miniHotdog', 'milkfries'],
#  ['Hashbrown', 'miniHotdog'],
#  ['Toppings', 'FriedSquid', 'Coolpeace'],
#  ['Chibab', 'Coolpeace'],
#  ['FriedSquid', 'Teokboki', 'FriedOdeng', 'Odengtang'],
#  ['Chibab', 'Cider', 'Coolpeace'],
#  ['Teokboki', 'Pepsi'],
#  ['miniHotdog', 'Teokboki'],
#  ['Chibab', 'Coolpeace', 'Coolpeace'],
#  ['Cheeseball'],
#  ['Teokboki', 'Coolpeace'],
#  ['FriedShrimp'],
#  ['Teokboki', 'Coolpeace'],
#  ['Cheeseball'],
#  ['Toppings'],
#  ['Chibab', 'Pepsi'],
#  ['Coolpeace', 'Yakimandu', 'miniHotdog'],
#  ['Toppings', 'Teokboki'],
#  ['Menbo', 'Toppings'],
#  ['Chibab'],
#  ['Toppings', 'Toppings'],
#  ['Sotteock', 'Toppings']]

# %%
# apriori 알고리즘
from mlxtend.frequent_patterns import apriori, association_rules
# 연관분석용 데이터 파일 변환
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import matplotlib.pyplot as plt

# %%
te = TransactionEncoder()
ted = te.fit(basket).transform(basket)
ted
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df = pd.DataFrame(ted, columns=te.columns_)
df
# Out:
#       Cass  Chamisl  CheeseStick  Cheeseball  Chibab  Cider  Coolpeace   Crab  \
# 0    False    False        False       False   False  False      False  False
# 1    False    False        False       False    True  False      False  False
# 2    False    False        False       False   False  False      False  False
# 3    False    False        False       False    True  False      False  False
# 4    False    False        False       False   False  False      False  False
# ..     ...      ...          ...         ...     ...    ...        ...    ...
# 443  False    False        False       False   False  False      False  False
# 444  False    False        False       False   False  False      False  False
# 445  False    False        False       False    True  False      False  False
# 446  False    False        False       False   False  False      False  False
# 447  False    False        False       False   False  False      False  False
#
#      FriedOdeng  FriedShrimp  ...  SPFries  Selfjumeokbab  Sotteock  Teokboki  \
# 0         False        False  ...    False          False     False     False
# 1         False        False  ...    False          False     False      True
# 2         False        False  ...    False          False      True     False
# 3         False        False  ...    False          False     False     False
# 4         False        False  ...    False          False     False     False
# ..          ...          ...  ...      ...            ...       ...       ...
# 443       False        False  ...    False          False     False      True
# 444       False        False  ...    False          False     False     False
# 445       False        False  ...    False          False     False     False
# 446       False        False  ...    False          False     False     False
# 447       False        False  ...    False          False      True     False
#
#       Tera  Toppings  Water  Yakimandu  milkfries  miniHotdog
# 0    False     False  False      False      False       False
# 1    False     False  False      False      False       False
# 2    False     False  False      False      False       False
# 3    False     False  False      False      False       False
# 4    False     False  False      False      False       False
# ..     ...       ...    ...        ...        ...         ...
# 443  False      True  False      False      False       False
# 444  False      True  False      False      False       False
# 445  False     False  False      False      False       False
# 446  False      True  False      False      False       False
# 447  False      True  False      False      False       False
#
# [448 rows x 30 columns]

# %% [markdown]
# ## 2. 탐색적 데이터 분석

# %%
freq = df.sum().to_frame('Frequency')
freq_sort = freq.sort_values('Frequency', ascending = False)
print(freq_sort)
# Out:
#                Frequency
# Coolpeace            147
# Chibab               137
# Pepsi                123
# Teokboki             104
# Sotteock              48
# Menbo                 37
# Toppings              36
# FriedShrimp           24
# Hashbrown             23
# milkfries             23
# Selfjumeokbab         22
# miniHotdog            21
# FriedSquid            20
# Kimmari               19
# Cider                 18
# Cheeseball            16
# OranC                 11
# FriedOdeng            11
# FriesSet              10
# Odengtang              9
# SPFries                9
# Yakimandu              9
# Gyeranzzim             8
# Crab                   8
# Chamisl                6
# CheeseStick            6
# Jinro                  3
# Cass                   3
# Tera                   1
# Water                  1

# %%
freq_sort['Support'] = freq_sort['Frequency'] / len(df)
print(freq_sort)
# Out:
#                Frequency   Support
# Coolpeace            147  0.328125
# Chibab               137  0.305804
# Pepsi                123  0.274554
# Teokboki             104  0.232143
# Sotteock              48  0.107143
# Menbo                 37  0.082589
# Toppings              36  0.080357
# FriedShrimp           24  0.053571
# Hashbrown             23  0.051339
# milkfries             23  0.051339
# Selfjumeokbab         22  0.049107
# miniHotdog            21  0.046875
# FriedSquid            20  0.044643
# Kimmari               19  0.042411
# Cider                 18  0.040179
# Cheeseball            16  0.035714
# OranC                 11  0.024554
# FriedOdeng            11  0.024554
# FriesSet              10  0.022321
# Odengtang              9  0.020089
# SPFries                9  0.020089
# Yakimandu              9  0.020089
# Gyeranzzim             8  0.017857
# Crab                   8  0.017857
# Chamisl                6  0.013393
# CheeseStick            6  0.013393
# Jinro                  3  0.006696
# Cass                   3  0.006696
# Tera                   1  0.002232
# Water                  1  0.002232

# %%
freq_sort['Frequency'].plot(kind='bar', title='FrequentItems');

# %%
freq_sort['Support'].hist();

# %% [markdown]
# ## 3. 연관규칙 생성

# %%
freq_items = apriori(df, min_support=0.01, use_colnames=True)
print(freq_items)
# Out:
#      support                       itemsets
# 0   0.013393                      (Chamisl)
# 1   0.013393                  (CheeseStick)
# 2   0.035714                   (Cheeseball)
# 3   0.305804                       (Chibab)
# 4   0.040179                        (Cider)
# ..       ...                            ...
# 57  0.015625      (Teokboki, Selfjumeokbab)
# 58  0.017857           (Sotteock, Teokboki)
# 59  0.011161           (Teokboki, Toppings)
# 60  0.011161         (Teokboki, miniHotdog)
# 61  0.011161  (Teokboki, Coolpeace, Chibab)
#
# [62 rows x 2 columns]

# %%
rules = association_rules(freq_items, metric = 'confidence', min_threshold = 0.5)

rules
# Out:
#           antecedents  consequents  antecedent support  consequent support  \
# 0        (Gyeranzzim)     (Chibab)            0.017857            0.305804
# 1              (Crab)      (Pepsi)            0.017857            0.274554
# 2           (Kimmari)   (Teokboki)            0.042411            0.232143
# 3  (Teokboki, Chibab)  (Coolpeace)            0.022321            0.328125
#
#     support  confidence      lift  leverage  conviction
# 0  0.011161    0.625000  2.043796  0.005700    1.851190
# 1  0.011161    0.625000  2.276423  0.006258    1.934524
# 2  0.022321    0.526316  2.267206  0.012476    1.621032
# 3  0.011161    0.500000  1.523810  0.003836    1.343750

# %%
rules = rules[(rules['lift'] > 1)]
rules.sort_values(by = 'confidence', ascending = False)
# Out:
#           antecedents  consequents  antecedent support  consequent support  \
# 0        (Gyeranzzim)     (Chibab)            0.017857            0.305804
# 1              (Crab)      (Pepsi)            0.017857            0.274554
# 2           (Kimmari)   (Teokboki)            0.042411            0.232143
# 3  (Teokboki, Chibab)  (Coolpeace)            0.022321            0.328125
#
#     support  confidence      lift  leverage  conviction
# 0  0.011161    0.625000  2.043796  0.005700    1.851190
# 1  0.011161    0.625000  2.276423  0.006258    1.934524
# 2  0.022321    0.526316  2.267206  0.012476    1.621032
# 3  0.011161    0.500000  1.523810  0.003836    1.343750

# %% [markdown]
# - 조건부에 '치밥'이 있는 규칙

# %%
rules[rules.antecedents.apply(lambda x:'Chibab' in x)]
# Out:
#           antecedents  consequents  antecedent support  consequent support  \
# 3  (Teokboki, Chibab)  (Coolpeace)            0.022321            0.328125
#
#     support  confidence     lift  leverage  conviction
# 3  0.011161         0.5  1.52381  0.003836     1.34375

# %%
rules[rules.antecedents.apply(lambda x:'Gyeranzzim' in x)]
# Out:
#     antecedents consequents  antecedent support  consequent support   support  \
# 0  (Gyeranzzim)    (Chibab)            0.017857            0.305804  0.011161
#
#    confidence      lift  leverage  conviction
# 0       0.625  2.043796    0.0057     1.85119

# %% [markdown]
# - 결론구에 '치밥'이 있는 규칙

# %%
rules[rules.consequents.apply(lambda x:'Chibab' in x)]
# Out:
#     antecedents consequents  antecedent support  consequent support   support  \
# 0  (Gyeranzzim)    (Chibab)            0.017857            0.305804  0.011161
#
#    confidence      lift  leverage  conviction
# 0       0.625  2.043796    0.0057     1.85119
